# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import random

from DCmatch import Match

from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
folder = os.fsencode("seasons/bettingSeasons")
dataframes = []
for file in sorted(os.listdir(folder)):
    filename = os.fsdecode(file)
    if filename.endswith(".csv"):
        print(filename)
        df = pd.read_csv("seasons/bettingSeasons/" + filename)
        dataframes.append(df)

data = pd.concat(dataframes, axis=0)
# Out:
# 1920-Copy1.csv
# 2021-Copy1.csv
# 2122-Copy1.csv
# 2223-Copy1.csv
# 2324-Copy1.csv
# 2425-Copy1.csv
# E0 (1).csv

# %%
data = data[[
    "Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR", "MaxH", "MaxD", "MaxA"
]]

# %%
data.describe()
# Out:
#               FTHG         FTAG         MaxH         MaxD         MaxA
# count  2490.000000  2490.000000  2490.000000  2490.000000  2490.000000
# mean      1.557028     1.318876     3.101189     4.524060     4.994863
# std       1.321759     1.222005     2.419381     1.562595     5.052503
# min       0.000000     0.000000     1.090000     3.100000     1.170000
# 25%       1.000000     0.000000     1.700000     3.650000     2.250000
# 50%       1.000000     1.000000     2.360000     4.000000     3.320000
# 75%       2.000000     2.000000     3.477500     4.750000     5.587500
# max       9.000000     9.000000    22.000000    17.000000    50.000000

# %%
simpleData = data[["Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG"]]
simpleData
# Out:
#            Date        HomeTeam          AwayTeam  FTHG  FTAG
# 0    09/08/2019       Liverpool           Norwich     4     1
# 1    10/08/2019        West Ham          Man City     0     5
# 2    10/08/2019     Bournemouth  Sheffield United     1     1
# 3    10/08/2019         Burnley       Southampton     3     0
# 4    10/08/2019  Crystal Palace           Everton     0     0
# ..          ...             ...               ...   ...   ...
# 205  07/01/2026          Fulham           Chelsea     2     1
# 206  07/01/2026        Man City          Brighton     1     1
# 207  07/01/2026         Burnley        Man United     2     2
# 208  07/01/2026       Newcastle             Leeds     4     3
# 209  08/01/2026         Arsenal         Liverpool     0     0
#
# [2490 rows x 5 columns]

# %%
uniqueTeams = data["HomeTeam"].unique()

# %%
teamsIndex = {}
for i in range(len(uniqueTeams)):
    teamsIndex[uniqueTeams[i]] = i
teamsIndex
# Out:
# {'Liverpool': 0,
#  'West Ham': 1,
#  'Bournemouth': 2,
#  'Burnley': 3,
#  'Crystal Palace': 4,
#  'Watford': 5,
#  'Tottenham': 6,
#  'Leicester': 7,
#  'Newcastle': 8,
#  'Man United': 9,
#  'Arsenal': 10,
#  'Aston Villa': 11,
#  'Brighton': 12,
#  'Everton': 13,
#  'Norwich': 14,
#  'Southampton': 15,
#  'Man City': 16,
#  'Sheffield United': 17,
#  'Chelsea': 18,
#  'Wolves': 19,
#  'Fulham': 20,
#  'West Brom': 21,
#  'Leeds': 22,
#  'Brentford': 23,
#  "Nott'm Forest": 24,
#  'Luton': 25,
#  'Ipswich': 26,
#  'Sunderland': 27}

# %%
dates = pd.to_datetime(simpleData["Date"], format="%d/%m/%Y")
simpleData["Week"] = (
    dates.dt.day
    + dates.dt.month * 12
    + dates.dt.year * 365
) // 7
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/75332271.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   simpleData["Week"] = (

# %%
from scipy.optimize import minimize
def phi(t):
    return np.exp(-0.03*t)

def logLikelihood(parameters, data):
    numTeams = int((len(parameters) - 2) // 2)
    
    attackStrengths = np.array(parameters[0:numTeams])
    defenceStrengths = np.array(parameters[numTeams:numTeams*2])
    
    homeAdv = parameters[-2]
    rho = parameters[-1]
    t = np.array(data["Week"])[-1]
    ll = 0

    for tk, row in data.iterrows():
        i = teamsIndex.get(row["HomeTeam"])
        j = teamsIndex.get(row["AwayTeam"])
        x = int(row["FTHG"])
        y = int(row["FTAG"])
        week = int(row["Week"])

        lamd = attackStrengths[i] * defenceStrengths[j] * homeAdv
        mu = attackStrengths[j] * defenceStrengths[i]

        ll += (np.log(Match.tauFunc(lamd, mu, rho, x, y) + 1e-7) - lamd + x*np.log(lamd) - mu + y*np.log(mu)) * phi(t - week)
    
    return -ll

# %%
from scipy.optimize import minimize
np.random.seed(1008)
def getNewEstimates(results: pd.DataFrame):
    rng = np.random.default_rng(123)
    init_att = rng.uniform(0.8, 2, size=len(uniqueTeams))
    init_def = rng.uniform(0.8, 1.3, size=len(uniqueTeams))
    init_home = 1.1
    init_rho = 0.0

    init = np.concatenate([init_att, init_def, [init_home, init_rho]])

    bounds = [(1e-6, None)] * (2*len(uniqueTeams)) + [(1e-6, None), (-0.99, 0.99)]

    result = minimize(
        logLikelihood,
        init,
        args=(results.tail(n=400),),
        bounds=bounds,
        options={'maxiter': 10000, 'disp': True},
    )
    return result.x

# %%
import csv
len(data["HomeTeam"])
# Out:
# 2490

# %%
currentEstimates = getNewEstimates(simpleData)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.52236D+02    |proj g|=  7.17633D+00
#
# At iterate    1    f=  2.38470D+02    |proj g|=  2.19062D+00
#
# At iterate    2    f=  2.32728D+02    |proj g|=  4.60165D+01
#
# At iterate    3    f=  2.27380D+02    |proj g|=  4.23333D+00
#
# At iterate    4    f=  2.26140D+02    |proj g|=  1.47270D+00
#
# At iterate    5    f=  2.25172D+02    |proj g|=  2.93591D+00
#
# At iterate    6    f=  2.24228D+02    |proj g|=  1.22239D+00
#
# At iterate    7    f=  2.23653D+02    |proj g|=  9.87500D-01
#
# At iterate    8    f=  2.23386D+02    |proj g|=  9.27093D-01
#
# At iterate    9    f=  2.23266D+02    |proj g|=  5.62704D-01
#
# At iterate   10    f=  2.23239D+02    |proj g|=  2.81005D-01
#
# At iterate   11    f=  2.23229D+02    |proj g|=  1.20670D-01
#
# At iterate   12    f=  2.23228D+02    |proj g|=  9.04976D-02
#
# At iterate   13    f=  2.23227D+02    |proj g|=  5.06049D-02
#
# At iterate   14    f=  2.23227D+02    |proj g|=  5.63489D-02
#
# At iterate   15    f=  2.23227D+02    |proj g|=  3.91509D-02
#
# At iterate   16    f=  2.23227D+02    |proj g|=  5.50244D-03
#
# At iterate   17    f=  2.23227D+02    |proj g|=  5.30349D-03
#
# At iterate   18    f=  2.23227D+02    |proj g|=  5.57634D-03
#
# At iterate   19    f=  2.23227D+02    |proj g|=  4.01599D-03
#
# At iterate   20    f=  2.23227D+02    |proj g|=  3.48166D-03
#
# At iterate   21    f=  2.23227D+02    |proj g|=  9.66338D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     21     23     45     0     0   9.663D-04   2.232D+02
#   F =   223.22727230879266
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
teamsLookup = {v: k for k, v in teamsIndex.items()}

# %%
homeTeams = ["Man City", "Brentford", "Bournemouth", "Everton", "Crystal Palace", "Fulham", "Newcastle", "Burnley"]
awayTeams = ["Brighton", "Sunderland", "Tottenham", "Wolves", "Aston Villa", "Chelsea", "Leeds", "Man United"]
for i in range(len(homeTeams)):
    match = Match(currentEstimates[teamsIndex.get(homeTeams[i])], currentEstimates[teamsIndex.get(homeTeams[i]) + 28], currentEstimates[teamsIndex.get(awayTeams[i])], currentEstimates[teamsIndex.get(awayTeams[i]) + 28], currentEstimates[-2], currentEstimates[-1], 8)
    probs = 1 / np.array(match.getOutcomeProbs())
    print(f"{homeTeams[i]}  {probs[0]}  -  {probs[1]}  -  {probs[2]}  {awayTeams[i]}")
# Out:
# Man City  1.6578523645900767  -  4.152937752089484  -  6.409575150815041  Brighton
# Brentford  1.959912965068412  -  3.2149908357181896  -  5.595019585898151  Sunderland
# Bournemouth  2.1081423325313406  -  3.977858309107562  -  3.646212812557036  Tottenham
# Everton  1.9455730686904071  -  3.247361070512196  -  5.615760503257693  Wolves
# Crystal Palace  3.688256122750074  -  2.954440702003191  -  2.5615041754188224  Aston Villa
# Fulham  3.1204007115438626  -  3.2784772771985047  -  2.670165037654222  Chelsea
# Newcastle  1.7750827490479422  -  4.414844649021865  -  4.758790134058489  Leeds
# Burnley  3.9184537577919794  -  3.6698366073067743  -  2.117273227979494  Man United

# %%
estimatesAtTimeT = []
for i in range(380, len(data["HomeTeam"]), 10):
    estimatesAtTimeT.append(getNewEstimates(simpleData.head(n=i)))
    print(f"Estimates at t={i} done")

with open("newEstimatesOvernight.csv", "w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(estimatesAtTimeT)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.81420D+02    |proj g|=  1.32524D+01
#
# At iterate    1    f=  3.62620D+02    |proj g|=  2.23982D+00
#
# At iterate    2    f=  3.54284D+02    |proj g|=  4.80869D+01
#
# At iterate    3    f=  3.44909D+02    |proj g|=  3.90977D+01
#
# At iterate    4    f=  3.25749D+02    |proj g|=  2.38626D+01
#
# At iterate    5    f=  3.18634D+02    |proj g|=  5.73140D+00
#
# At iterate    6    f=  3.17166D+02    |proj g|=  2.08834D+00
#
# At iterate    7    f=  3.16785D+02    |proj g|=  6.64130D-01
#
# At iterate    8    f=  3.16734D+02    |proj g|=  8.97739D-01
#
# At iterate    9    f=  3.16719D+02    |proj g|=  8.16732D-01
#
# At iterate   10    f=  3.16711D+02    |proj g|=  3.20841D-01
#
# At iterate   11    f=  3.16710D+02    |proj g|=  1.35913D-01
#
# At iterate   12    f=  3.16709D+02    |proj g|=  5.73266D-02
#
# At iterate   13    f=  3.16709D+02    |proj g|=  1.75646D-02
#
#
# At iterate   17    f=  1.91164D+02    |proj g|=  1.52170D-02
#
# At iterate   18    f=  1.91164D+02    |proj g|=  5.79519D-03
#
# At iterate   19    f=  1.91164D+02    |proj g|=  2.87343D-03
#
# At iterate   20    f=  1.91164D+02    |proj g|=  3.73461D-03
#
# At iterate   21    f=  1.91164D+02    |proj g|=  2.10036D-03
#
# At iterate   22    f=  1.91164D+02    |proj g|=  1.08571D-03
# Estimates at t=540 done
# At iterate   23    f=  1.91164D+02    |proj g|=  2.20268D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     23     27     48     0     0   2.203D-03   1.912D+02
#   F =   191.16351730157928
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.30970D+02    |proj g|=  6.13243D+00
#
# At iterate    1    f=  2.15461D+02    |proj g|=  1.92029D+00
#
# At iterate    2    f=  2.09353D+02    |proj g|=  2.49501D+01
#
# At iterate    3    f=  2.03511D+02    |proj g|=  1.21276D+01
#
# At iterate    4    f=  2.00434D+02    |proj g|=  1.03469D+01
#
# At iterate    5    f=  1.98727D+02    |proj g|=  1.39557D+00
#
# At iterate    6    f=  1.97942D+02    |proj g|=  1.14863D+00
#
# At iterate    7    f=  1.97183D+02    |proj g|=  1.16677D+00
#
# At iterate    8    f=  1.96762D+02    |proj g|=  1.16573D+00
#
# At iterate    9    f=  1.96530D+02    |proj g|=  1.15821D+00
#
# At iterate   10    f=  1.96468D+02    |proj g|=  5.20188D-01
#
# At iterate   11    f=  1.96457D+02    |proj g|=  1.44308D-01
#
# At iterate   12    f=  1.96455D+02    |proj g|=  1.16202D-01
#
# At iterate   13    f=  1.96454D+02    |proj g|=  4.10739D-01
#
# At iterate   14    f=  1.96452D+02    |proj g|=  7.90038D-02
#
# At iterate   15    f=  1.96452D+02    |proj g|=  3.99723D-02
#
# At iterate   16    f=  1.96452D+02    |proj g|=  3.65532D-02
#
# At iterate   17    f=  1.96452D+02    |proj g|=  1.06616D-01
#
# At iterate   18    f=  1.96452D+02    |proj g|=  1.50095D-02
#
# At iterate   19    f=  1.96452D+02    |proj g|=  9.22284D-03
#
# At iterate   20    f=  1.96452D+02    |proj g|=  4.26326D-03
#
# At iterate   21    f=  1.96451D+02    |proj g|=  2.10889D-03
#
# At iterate   22    f=  1.96451D+02    |proj g|=  2.84786D-03
# Estimates at t=550 done
# At iterate   23    f=  1.96451D+02    |proj g|=  6.08225D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     23     28     49     0     0   6.082D-04   1.965D+02
#   F =   196.45149408648234
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.42970D+02    |proj g|=  6.92555D+00
#
# At iterate    1    f=  2.27111D+02    |proj g|=  1.67366D+00
#
# At iterate    2    f=  2.22113D+02    |proj g|=  2.21197D+01
#
# At iterate    3    f=  2.16648D+02    |proj g|=  1.30736D+01
#
# At iterate    4    f=  2.10621D+02    |proj g|=  1.15787D+01
#
# At iterate    5    f=  2.09264D+02    |proj g|=  2.62409D+00
#
# At iterate    6    f=  2.07757D+02    |proj g|=  1.13575D+00
#
# At iterate    7    f=  2.07217D+02    |proj g|=  1.02593D+00
#
# At iterate    8    f=  2.06529D+02    |proj g|=  1.03267D+00
#
# At iterate    9    f=  2.06063D+02    |proj g|=  1.04328D+00
#
# At iterate   10    f=  2.05916D+02    |proj g|=  8.04212D-01
#
# At iterate   11    f=  2.05862D+02    |proj g|=  2.31589D-01
#
# At iterate   12    f=  2.05857D+02    |proj g|=  1.33562D-01
#
# At iterate   13    f=  2.05856D+02    |proj g|=  1.54111D-01
#
# At iterate   14    f=  2.05856D+02    |proj g|=  5.74630D-02
#
# At iterate   15    f=  2.05856D+02    |proj g|=  4.10694D-02
#
# At iterate   16    f=  2.05855D+02    |proj g|=  2.42096D-02
#
# At iterate   17    f=  2.05855D+02    |proj g|=  3.13861D-02
#
# At iterate   18    f=  2.05855D+02    |proj g|=  2.44881D-02
#
# At iterate   19    f=  2.05855D+02    |proj g|=  3.35092D-03
#
# At iterate   20    f=  2.05855D+02    |proj g|=  1.86446D-03
#
# At iterate   21    f=  2.05855D+02    |proj g|=  2.43290D-03
# Estimates at t=560 done
# At iterate   22    f=  2.05855D+02    |proj g|=  3.71472D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     22     25     48     0     0   3.715D-03   2.059D+02
#   F =   205.85526223395439
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.51778D+02    |proj g|=  9.48955D+00
#
# At iterate    1    f=  2.35086D+02    |proj g|=  1.76560D+00
#
# At iterate    2    f=  2.29876D+02    |proj g|=  2.06089D+01
#
# At iterate    3    f=  2.24432D+02    |proj g|=  1.64203D+01
#
# At iterate    4    f=  2.17169D+02    |proj g|=  2.70500D+01
#
# At iterate    5    f=  2.14325D+02    |proj g|=  1.17975D+00
#
# At iterate    6    f=  2.13756D+02    |proj g|=  1.13670D+00
#
# At iterate    7    f=  2.12541D+02    |proj g|=  3.96076D+00
#
# At iterate    8    f=  2.12056D+02    |proj g|=  2.10844D+00
#
# At iterate    9    f=  2.11668D+02    |proj g|=  1.28976D+00
#
# At iterate   10    f=  2.11399D+02    |proj g|=  7.85411D-01
#
# At iterate   11    f=  2.11360D+02    |proj g|=  7.93514D-01
#
# At iterate   12    f=  2.11349D+02    |proj g|=  5.96634D-01
#
# ...
#
# At iterate    1    f=  4.44839D+02    |proj g|=  3.18928D+00
#
# At iterate    2    f=  4.37465D+02    |proj g|=  4.21968D+01
#
# At iterate    3    f=  4.32678D+02    |proj g|=  2.25258D+01
#
# At iterate    4    f=  4.23207D+02    |proj g|=  1.77081D+00
#
# At iterate    5    f=  4.16974D+02    |proj g|=  6.60966D+00
#
# At iterate    6    f=  4.12981D+02    |proj g|=  3.66003D+00
#
# At iterate    7    f=  4.12415D+02    |proj g|=  2.62318D+00
#
# At iterate    8    f=  4.12019D+02    |proj g|=  1.00865D+00
#
# At iterate    9    f=  4.11941D+02    |proj g|=  7.44495D-01
#
# At iterate   10    f=  4.11880D+02    |proj g|=  3.85774D-01
#
# At iterate   11    f=  4.11870D+02    |proj g|=  2.77782D-01
#
# At iterate   12    f=  4.11868D+02    |proj g|=  2.03539D-01
#
# At iterate   13    f=  4.11867D+02    |proj g|=  3.92288D-01
#
# At iterate   14    f=  4.11866D+02    |proj g|=  7.60622D-02
#
# At iterate   15    f=  4.11866D+02    |proj g|=  3.63229D-02
-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     19     22     44     0     0   4.360D-03   4.476D+02
#   F =   447.64994175244152
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.24951D+02    |proj g|=  2.03230D+01
#
# At iterate    1    f=  5.03000D+02    |proj g|=  3.85284D+00
#
# At iterate    2    f=  4.94943D+02    |proj g|=  4.18592D+01
#
# At iterate    3    f=  4.90009D+02    |proj g|=  2.67166D+01
#
# At iterate    4    f=  4.75592D+02    |proj g|=  2.71958D+00
#
# At iterate    5    f=  4.69254D+02    |proj g|=  3.22136D+00
#
# At iterate    6    f=  4.65910D+02    |proj g|=  7.14019D+00
#
# At iterate    7    f=  4.64980D+02    |proj g|=  3.20838D+00
#
# At iterate    8    f=  4.64595D+02    |proj g|=  8.86541D-01
#
# At iterate    9    f=  4.64452D+02    |proj g|=  7.52073D-01
#
# At iterate   10    f=  4.64399D+02    |proj g|=  7.00310D-01
#
# At iterate   11    f=  4.64390D+02    |proj g|=  5.07815D-01
#
# At iterate   12    f=  4.64384D+02    |proj g|=  4.87489D-02
#
# At iterate   13    f=  4.64384D+02    |proj g|=  3.94778D-02
#
# At iterate   14    f=  4.64384D+02    |proj g|=  1.05103D-01
#
# At iterate   15    f=  4.64384D+02    |proj g|=  2.14357D-02
#
# At iterate   16    f=  4.64384D+02    |proj g|=  1.33525D-02
#
# At iterate   17    f=  4.64384D+02    |proj g|=  4.79758D-03
#
# At iterate   18    f=  4.64384D+02    |proj g|=  2.21121D-03
# Estimates at t=2460 done
# At iterate   19    f=  4.64384D+02    |proj g|=  8.15135D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     19     23     45     0     0   8.151D-03   4.644D+02
#   F =   464.38359311468730
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.28720D+02    |proj g|=  8.01839D+00
#
# At iterate    1    f=  2.15455D+02    |proj g|=  1.99861D+00
#
# At iterate    2    f=  2.13378D+02    |proj g|=  5.86136D+01
#
# At iterate    3    f=  2.05531D+02    |proj g|=  7.93793D+00
#
# At iterate    4    f=  2.04583D+02    |proj g|=  2.27394D+00
#
# At iterate    5    f=  2.03108D+02    |proj g|=  1.88597D+00
#
# At iterate    6    f=  2.02481D+02    |proj g|=  1.89216D+00
#
# At iterate    7    f=  2.02120D+02    |proj g|=  1.21058D+00
#
# At iterate    8    f=  2.01732D+02    |proj g|=  8.20847D-01
#
# At iterate    9    f=  2.01628D+02    |proj g|=  6.33315D-01
#
# At iterate   10    f=  2.01554D+02    |proj g|=  3.39418D-01
#
# At iterate   11    f=  2.01542D+02    |proj g|=  2.91348D-01
#
# At iterate   12    f=  2.01541D+02    |proj g|=  2.22420D-01
#
# At iterate   13    f=  2.01541D+02    |proj g|=  2.41556D-02
#
# At iterate   14    f=  2.01541D+02    |proj g|=  1.64874D-02
#
# At iterate   15    f=  2.01541D+02    |proj g|=  1.32559D-02
#
# At iterate   16    f=  2.01541D+02    |proj g|=  4.03816D-02
#
# At iterate   17    f=  2.01541D+02    |proj g|=  2.37321D-02
#
# At iterate   18    f=  2.01541D+02    |proj g|=  2.72848D-03
#
# At iterate   19    f=  2.01541D+02    |proj g|=  1.80194D-03
#
# At iterate   20    f=  2.01541D+02    |proj g|=  1.37561D-03
# Estimates at t=2470 done
# At iterate   21    f=  2.01541D+02    |proj g|=  7.33280D-04
#
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     21     23     47     0     0   7.333D-04   2.015D+02
#   F =   201.54077315343849
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.43240D+02    |proj g|=  7.31338D+00
#
# At iterate    1    f=  2.29668D+02    |proj g|=  2.10261D+00
#
# At iterate    2    f=  2.24640D+02    |proj g|=  2.92929D+01
#
# At iterate    3    f=  2.19398D+02    |proj g|=  1.45770D+01
#
# At iterate    4    f=  2.17502D+02    |proj g|=  4.16033D+00
#
# At iterate    5    f=  2.16504D+02    |proj g|=  1.19325D+00
#
# At iterate    6    f=  2.16086D+02    |proj g|=  1.22166D+00
#
# At iterate    7    f=  2.15762D+02    |proj g|=  1.22697D+00
#
# At iterate    8    f=  2.15696D+02    |proj g|=  9.23747D-01
#
# At iterate    9    f=  2.15593D+02    |proj g|=  4.38186D-01
#
# At iterate   10    f=  2.15575D+02    |proj g|=  3.10115D-01
#
# At iterate   11    f=  2.15564D+02    |proj g|=  1.82749D-01
#
# At iterate   12    f=  2.15561D+02    |proj g|=  7.18643D-02
#
# At iterate   13    f=  2.15560D+02    |proj g|=  4.30617D-02
#
# At iterate   14    f=  2.15560D+02    |proj g|=  2.73104D-02
#
# At iterate   15    f=  2.15560D+02    |proj g|=  1.52113D-02
#
# At iterate   16    f=  2.15560D+02    |proj g|=  3.81135D-03
#
# At iterate   17    f=  2.15560D+02    |proj g|=  3.73461D-03
#
# At iterate   18    f=  2.15560D+02    |proj g|=  1.99805D-03
#
# At iterate   19    f=  2.15560D+02    |proj g|=  1.25340D-03
# Estimates at t=2480 done
#
# At iterate   20    f=  2.15560D+02    |proj g|=  1.31308D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     20     23     47     0     0   1.313D-03   2.156D+02
#   F =   215.56032061654946
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
newEstimates = []

with open("newEstimatesOvernight.csv", newline="") as my_csv:
    csvReader = csv.reader(my_csv)
    for row in csvReader:
        newEstimates.append([float(x) for x in row])

# %%
strengthsOverTime = [[row[i] for row in newEstimates] for i in range(len(newEstimates[0]))]

# %%
teamsLookup = {v: k for k, v in teamsIndex.items()}

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(strengthsOverTime[teamsIndex.get("Liverpool")], label="Liverpool", color="maroon")
ax[0].plot(strengthsOverTime[teamsIndex.get("Man City")], label="Man City", color="lightseagreen")
ax[0].plot(strengthsOverTime[teamsIndex.get("Arsenal")], label="Arsenal", color="red")
ax[0].set_title("Attack Strengths 2020/21 - 2025/26 Seasons")
ax[0].vlines(38, 1.1, 2.4, color="grey", linestyle="dotted", label="End of Season")
ax[0].vlines(76, 1.1, 2.4, color="grey", linestyle="dotted")
ax[0].vlines(114, 1.1, 2.4, color="grey", linestyle="dotted")
ax[0].vlines(152, 1.1, 2.4, color="grey", linestyle="dotted")
ax[0].vlines(190, 1.1, 2.4, color="grey", linestyle="dotted")
ax[0].legend(prop={'size': 6})
ax[0].text(0, 1.15, "2020/21")
ax[0].text(42, 1.15, "2021/22")
ax[0].text(80, 1.15, "2022/23")
ax[0].text(118, 1.15, "2023/24")
ax[0].text(156, 1.15, "2024/25")
ax[0].text(194, 1.15, "25/26")

ax[1].plot(strengthsOverTime[teamsIndex.get("Liverpool")+28], label="Liverpool", color="maroon")
ax[1].plot(strengthsOverTime[teamsIndex.get("Man City")+28], label="Man City", color="lightseagreen")
ax[1].plot(strengthsOverTime[teamsIndex.get("Arsenal")+28], label="Arsenal", color="red")
ax[1].set_title("Defence Strengths 2020/21 - 2025/26 Seasons")
ax[1].invert_yaxis()
ax[1].vlines(38, 0.5, 1.2, color="grey", linestyle="dotted", label="End of Season")
ax[1].vlines(76, 0.5, 1.2, color="grey", linestyle="dotted")
ax[1].vlines(114, 0.5, 1.2, color="grey", linestyle="dotted")
ax[1].vlines(152, 0.5, 1.2, color="grey", linestyle="dotted")
ax[1].vlines(190, 0.5, 1.2, color="grey", linestyle="dotted")
ax[1].legend(prop={'size': 6})
ax[1].text(0, 1.15, "2020/21")
ax[1].text(42, 1.15, "2021/22")
ax[1].text(80, 1.15, "2022/23")
ax[1].text(118, 1.15, "2023/24")
ax[1].text(156, 1.15, "2024/25")
ax[1].text(194, 1.15, "25/26")
fig.savefig("top3.jpg")

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(strengthsOverTime[-1], color="grey")
ax[0].hlines(np.mean(strengthsOverTime[-1]), 0, 212, linestyle="dotted", color="black")
ax[0].set_title("Rho Parameter 2020/21 - 2025/26")
ax[1].plot(strengthsOverTime[-2], color="grey")
ax[1].hlines(np.mean(strengthsOverTime[-2]), 0, 212, linestyle="dotted", color="black")
ax[1].set_title("Home Advantage Parameter 2020/21 - 2025/26")
fig.savefig("paramsP")
# Out:
# Text(0.5, 1.0, 'Home Advantage Parameter 2020/21 - 2025/26')

# %%
np.mean(strengthsOverTime[-2])
# Out:
# 1.1670876258714393

# %%
teamStrengths = [[] for i in range(58)]

for i in range(len(simpleData["AwayTeam"])):
    if i < 380:
        for j in range(58):
            teamStrengths[j].append(0)
    else:
        for j in range(58):
            teamStrengths[j].append(strengthsOverTime[j][(i-380) // 10])

# %%
attack = teamStrengths[0:28]
defence = teamStrengths[28:56]
homeAdvantage = teamStrengths[-2]
rho = teamStrengths[-1]

# %%
len(homeAdvantage)
# Out:
# 2490

# %%
home_idx = data["HomeTeam"].map(teamsIndex).to_numpy()
away_idx = data["AwayTeam"].map(teamsIndex).to_numpy()

# %%
t = np.arange(len(data["HomeTeam"]))

# %%
homeAttacks = []
homeDefences = []
awayAttacks = []
awayDefences = []

for i in range(len(data["HomeTeam"])):
    homeAttacks.append(attack[home_idx[i]][i])
    homeDefences.append(defence[home_idx[i]][i])
    awayAttacks.append(attack[away_idx[i]][i])
    awayDefences.append(defence[away_idx[i]][i])

homeProbs = []
drawProbs = []
awayProbs = []

for i in range(len(data["HomeTeam"])):
    thisMatch = Match(homeAttacks[i], homeDefences[i], awayAttacks[i], awayDefences[i], homeAdvantage[i], rho[i], 8)
    outcomes = thisMatch.getOutcomeProbs()
    homeProbs.append(outcomes[0])
    drawProbs.append(outcomes[1])
    awayProbs.append(outcomes[2])



data["attackH"]  = homeAttacks
data["defenceH"] = homeDefences
data["attackA"]  = awayAttacks
data["defenceA"] = awayDefences
data["rho"] = rho
data["homeAdv"] = homeAdvantage
data["homeProb"] = homeProbs
data["drawProb"] = drawProbs
data["awayProb"] = awayProbs
data["FairHomeOdds"] = 1 / data["homeProb"]
data["FairDrawOdds"] = 1 / data["drawProb"]
data["FairAwayOdds"] = 1 / data["awayProb"]

# %%
bettingFrame = data.tail(n=2110)
bettingFrame["HomeWin"] = np.where(bettingFrame["FTR"] == "H", 1, 0)
bettingFrame["Draw"] = np.where(bettingFrame["FTR"] == "D", 1, 0)
bettingFrame["AwayWin"] = np.where(bettingFrame["FTR"] == "A", 1, 0)
bettingFrame.head()
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/1802048398.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["HomeWin"] = np.where(bettingFrame["FTR"] == "H", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/1802048398.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Draw"] = np.where(bettingFrame["FTR"] == "D", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/1802048398.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["AwayWin"] = np.where(bettingFrame["FTR"] == "A", 1, 0)
#          Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  MaxH  MaxD   MaxA  \
# 0  12/09/2020          Fulham      Arsenal     0     3   A  6.55  4.55   1.60
# 1  12/09/2020  Crystal Palace  Southampton     1     0   H  3.36  3.36   2.50
# 2  12/09/2020       Liverpool        Leeds     4     3   H  1.35  6.50  10.75
# 3  12/09/2020        West Ham    Newcastle     0     2   A  2.24  3.70   3.60
# 4  13/09/2020       West Brom    Leicester     0     3   A  4.00  3.82   2.04
#
#     attackH  ...   homeAdv  homeProb  drawProb  awayProb  FairHomeOdds  \
# 0  1.077867  ...  1.342738  0.256029  0.272854  0.471117      3.905806
# 1  0.725293  ...  1.342738  0.237064  0.303230  0.459706      4.218275
# 2  2.010702  ...  1.342738  0.676324  0.195212  0.128464      1.478581
# 3  1.332293  ...  1.342738  0.559395  0.244834  0.195771      1.787646
# 4  0.999085  ...  1.342738  0.274875  0.282907  0.442218      3.638018
#
#    FairDrawOdds  FairAwayOdds  HomeWin  Draw  AwayWin
# 0      3.664968      2.122614        0     0        1
# 1      3.297823      2.175303        1     0        0
# 2      5.122624      7.784309        1     0        0
# 3      4.084399      5.108004        0     0        1
# 4      3.534736      2.261326        0     0        1
#
# [5 rows x 24 columns]

# %%
bettingFrame["ValueRatioHome"] = bettingFrame["MaxH"] * bettingFrame["homeProb"]
bettingFrame["ValueRatioDraw"] = bettingFrame["MaxD"] * bettingFrame["drawProb"]
bettingFrame["ValueRatioAway"] = bettingFrame["MaxA"] * bettingFrame["awayProb"]
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/551312071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioHome"] = bettingFrame["MaxH"] * bettingFrame["homeProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/551312071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioDraw"] = bettingFrame["MaxD"] * bettingFrame["drawProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/551312071.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioAway"] = bettingFrame["MaxA"] * bettingFrame["awayProb"]

# %%
threshold = 1.1

value_cols = ['ValueRatioHome', 'ValueRatioAway', 'ValueRatioDraw']

# Identify best outcome per row
best = bettingFrame[value_cols].idxmax(axis=1)
max_value = bettingFrame[value_cols].max(axis=1)

# Reset bets
bettingFrame[['HomeBet', 'AwayBet', 'DrawBet']] = 0

bettingFrame.loc[
    (max_value > threshold) & (best == 'ValueRatioHome'),
    'HomeBet'
] = 1

bettingFrame.loc[
    (max_value > threshold) & (best == 'ValueRatioAway'),
    'AwayBet'
] = 1

bettingFrame.loc[
    (max_value > threshold) & (best == 'ValueRatioDraw'),
    'DrawBet'
] = 1
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/3515713847.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame[['HomeBet', 'AwayBet', 'DrawBet']] = 0

# %%
bankroll = 1000
kellyFraction = 0.1

bettingFrame["kellyHomeFraction"] = bettingFrame["HomeBet"] * (bettingFrame["homeProb"] * (bettingFrame["MaxH"] - 1) - (1-bettingFrame["homeProb"])) / ((bettingFrame["MaxH"] - 1)) * kellyFraction
bettingFrame["kellyDrawFraction"] = bettingFrame["DrawBet"] * (bettingFrame["drawProb"] * (bettingFrame["MaxD"] - 1) - (1-bettingFrame["drawProb"])) / ((bettingFrame["MaxD"] - 1)) * kellyFraction
bettingFrame["kellyAwayFraction"] = bettingFrame["AwayBet"] * (bettingFrame["awayProb"] * (bettingFrame["MaxA"] - 1) - (1-bettingFrame["awayProb"])) / ((bettingFrame["MaxA"] - 1)) * kellyFraction
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/3784870960.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["kellyHomeFraction"] = bettingFrame["HomeBet"] * (bettingFrame["homeProb"] * (bettingFrame["MaxH"] - 1) - (1-bettingFrame["homeProb"])) / ((bettingFrame["MaxH"] - 1)) * kellyFraction
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/3784870960.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["kellyDrawFraction"] = bettingFrame["DrawBet"] * (bettingFrame["drawProb"] * (bettingFrame["MaxD"] - 1) - (1-bettingFrame["drawProb"])) / ((bettingFrame["MaxD"] - 1)) * kellyFraction
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/3784870960.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["kellyAwayFraction"] = bettingFrame["AwayBet"] * (bettingFrame["awayProb"] * (bettingFrame["MaxA"] - 1) - (1-bettingFrame["awayProb"])) / ((bettingFrame["MaxA"] - 1)) * kellyFraction

# %%
bettingFrame["flatProfit"] = bettingFrame["HomeWin"] * bettingFrame["HomeBet"] * bettingFrame["MaxH"] + bettingFrame["AwayWin"] * bettingFrame["AwayBet"] * bettingFrame["MaxA"] - (bettingFrame["HomeBet"] + bettingFrame["AwayBet"])
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/3863367311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["flatProfit"] = bettingFrame["HomeWin"] * bettingFrame["HomeBet"] * bettingFrame["MaxH"] + bettingFrame["AwayWin"] * bettingFrame["AwayBet"] * bettingFrame["MaxA"] - (bettingFrame["HomeBet"] + bettingFrame["AwayBet"])

# %%
bettingFrame.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'MaxH', 'MaxD',
#        'MaxA', 'attackH', 'defenceH', 'attackA', 'defenceA', 'rho', 'homeAdv',
#        'homeProb', 'drawProb', 'awayProb', 'FairHomeOdds', 'FairDrawOdds',
#        'FairAwayOdds', 'HomeWin', 'Draw', 'AwayWin', 'ValueRatioHome',
#        'ValueRatioDraw', 'ValueRatioAway', 'HomeBet', 'AwayBet', 'DrawBet',
#        'kellyHomeFraction', 'kellyDrawFraction', 'kellyAwayFraction',
#        'flatProfit', 'Bankroll', 'Stake', 'PnL'],
#       dtype='object')

# %%
starting_bankroll = 100
bankroll = starting_bankroll

bankroll_history = []
stake_history = []
pnl_history = []

for _, row in bettingFrame.iterrows():

    stake = 0.0
    pnl = 0.0

    # Home bet
    if row['HomeBet'] == 1:
        stake = bankroll * row['kellyHomeFraction']
        if row['HomeWin'] == 1:
            pnl = stake * (row['MaxH'] - 1)
        else:
            pnl = -stake

    # Draw bet
    elif row['DrawBet'] == 1:
        stake = bankroll * row['kellyDrawFraction']
        if row['Draw'] == 1:
            pnl = stake * (row['MaxD'] - 1)
        else:
            pnl = -stake

    # Away bet
    elif row['AwayBet'] == 1:
        stake = bankroll * row['kellyAwayFraction']
        if row['AwayWin'] == 1:
            pnl = stake * (row['MaxA'] - 1)
        else:
            pnl = -stake

    bankroll += pnl

    bankroll_history.append(bankroll)
    stake_history.append(stake)
    pnl_history.append(pnl)

bettingFrame['Bankroll'] = bankroll_history
bettingFrame['Stake'] = stake_history
bettingFrame['PnL'] = pnl_history
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/2287055301.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame['Bankroll'] = bankroll_history
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/2287055301.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame['Stake'] = stake_history
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_87424/2287055301.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame['PnL'] = pnl_history

# %%
bettingFrame = bettingFrame.reset_index()
bettingFrame.drop(["index"], axis=1)
# Out:
#             Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  MaxH  MaxD  \
# 0     12/09/2020          Fulham      Arsenal     0     3   A  6.55  4.55
# 1     12/09/2020  Crystal Palace  Southampton     1     0   H  3.36  3.36
# 2     12/09/2020       Liverpool        Leeds     4     3   H  1.35  6.50
# 3     12/09/2020        West Ham    Newcastle     0     2   A  2.24  3.70
# 4     13/09/2020       West Brom    Leicester     0     3   A  4.00  3.82
# ...          ...             ...          ...   ...   ...  ..   ...   ...
# 2105  07/01/2026          Fulham      Chelsea     2     1   H  3.50  3.70
# 2106  07/01/2026        Man City     Brighton     1     1   D  1.40  5.50
# 2107  07/01/2026         Burnley   Man United     2     2   D  5.00  4.00
# 2108  07/01/2026       Newcastle        Leeds     4     3   H  1.73  4.10
# 2109  08/01/2026         Arsenal    Liverpool     0     0   D  1.64  4.33
#
#        MaxA   attackH  ...  HomeBet  AwayBet  DrawBet  kellyHomeFraction  \
# 0      1.60  1.077867  ...        1        0        0           0.012198
# 1      2.50  0.725293  ...        0        1        0          -0.000000
# 2     10.75  2.010702  ...        0        1        0          -0.000000
# 3      3.60  1.332293  ...        1        0        0           0.020407
# 4      2.04  0.999085  ...        0        0        0           0.000000
# ...     ...       ...  ...      ...      ...      ...                ...
# 2105   2.12  1.395373  ...        0        0        0           0.000000
# 2106   8.50  2.008553  ...        0        1        0          -0.000000
# 2107   1.75  0.963505  ...        1        0        0           0.003887
# 2108   5.50  1.590797  ...        0        1        0          -0.000000
# 2109   5.60  1.864074  ...        0        0        0          -0.000000
#
#       kellyDrawFraction  kellyAwayFraction  flatProfit   Bankroll     Stake  \
# 0                   0.0          -0.000000        -1.0  98.780197  1.219803
# 1                   0.0           0.009951        -1.0  97.797236  0.982961
# 2                   0.0           0.003908        -1.0  97.415091  0.382145
# 3                  -0.0          -0.000000        -1.0  95.427160  1.987930
# 4                   0.0          -0.000000         0.0  95.427160  0.000000
# ...                 ...                ...         ...        ...       ...
# 2105                0.0          -0.000000         0.0  54.130189  0.000000
# 2106                0.0           0.002478        -1.0  53.996073  0.134116
# 2107                0.0          -0.000000        -1.0  53.786204  0.209869
# 2108                0.0           0.002541        -1.0  53.649524  0.136680
# 2109                0.0          -0.000000         0.0  53.649524  0.000000
#
#            PnL
# 0    -1.219803
# 1    -0.982961
# 2    -0.382145
# 3    -1.987930
# 4     0.000000
# ...        ...
# 2105  0.000000
# 2106 -0.134116
# 2107 -0.209869
# 2108 -0.136680
# 2109  0.000000
#
# [2110 rows x 37 columns]

# %%
fig, ax = plt.subplots()
ax.plot(bettingFrame["flatProfit"].cumsum()+100)
ax.plot(bettingFrame["Bankroll"])
ax.vlines(380, 40, 150)
ax.vlines(760, 40, 150)
ax.vlines(1140, 40, 150)
ax.vlines(1520, 40, 150)
ax.vlines(1900, 40, 150)

# %%
bettingFrame["Date"]
# Out:
# 0      12/09/2020
# 1      12/09/2020
# 2      12/09/2020
# 3      12/09/2020
# 4      13/09/2020
#           ...
# 205    07/01/2026
# 206    07/01/2026
# 207    07/01/2026
# 208    07/01/2026
# 209    08/01/2026
# Name: Date, Length: 2110, dtype: object

# %%
home_profits = bettingFrame.loc[bettingFrame["HomeBet"] > 0, "Profit"]
draw_profits = bettingFrame.loc[bettingFrame["DrawBet"] > 0, "Profit"]
away_profits = bettingFrame.loc[bettingFrame["AwayBet"] > 0, "Profit"]

# %%
sum(home_profits)
# Out:
# 0.9999999999999967

# %%
sum(away_profits)
# Out:
# -35.81

# %%
sum(draw_profits)
# Out:
# -56.31

# %%
plt.hist(home_profits, bins=30, alpha=0.5, label="Home Bets")
plt.hist(draw_profits, bins=30, alpha=0.5, label="Draw Bets")
plt.hist(away_profits, bins=30, alpha=0.5, label="Away Bets")

plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.title("Profit Distribution by Bet Type")
plt.legend()
plt.show()

# %%
bettingFrame.HomeBet.sum() + bettingFrame.DrawBet.sum() + bettingFrame.AwayBet.sum()
# Out:
# 2939

# %%
bettingFrame["Profit"].sum()
# Out:
# -57.78

# %%
-57.78 / 2939
# Out:
# -0.01965974821367812

# %%
cleanProfits = [x for x in bettingFrame.Profit if x!=0]

# %%
np.var(cleanProfits)
# Out:
# 2.8702859365182967

# %%
np.mean(cleanProfits)
# Out:
# -0.028674937965260546

# %%
import csv


with open("profitsMLE.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(cleanProfits)
