# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import random

from DCmatch import Match

from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
folder = os.fsencode("seasons/bettingSeasons")
dataframes = []
for file in sorted(os.listdir(folder)):
    filename = os.fsdecode(file)
    if filename.endswith(".csv"):
        print(filename)
        df = pd.read_csv("seasons/bettingSeasons/" + filename)
        dataframes.append(df)

data = pd.concat(dataframes, axis=0)
# Out:
# 1920-Copy1.csv
# 2021-Copy1.csv
# 2122-Copy1.csv
# 2223-Copy1.csv
# 2324-Copy1.csv
# 2425-Copy1.csv
# E0 (1).csv

# %%
data = data[[
    "Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR", "HS", "AS", "HST", "AST", 
    "B365H", "B365D", "B365A", "MaxH", "MaxD", "MaxA", "AvgH", "AvgD", "AvgA"
]]

# %%
data.describe()
# Out:
#               FTHG         FTAG           HS           AS          HST  \
# count  2480.000000  2480.000000  2480.000000  2480.000000  2480.000000
# mean      1.556452     1.319355    13.808871    11.627419     4.795161
# std       1.321937     1.222861     5.659471     5.188101     2.587083
# min       0.000000     0.000000     1.000000     1.000000     0.000000
# 25%       1.000000     0.000000    10.000000     8.000000     3.000000
# 50%       1.000000     1.000000    13.000000    11.000000     5.000000
# 75%       2.000000     2.000000    17.000000    15.000000     6.000000
# max       9.000000     9.000000    36.000000    37.000000    16.000000
#
#                AST        B365H        B365D        B365A         MaxH  \
# count  2480.000000  2480.000000  2480.000000  2480.000000  2480.000000
# mean      4.107258     2.896843     4.252157     4.429145     3.103379
# std       2.392966     2.066676     1.339878     3.748310     2.423028
# min       0.000000     1.060000     2.800000     1.140000     1.090000
# 25%       2.000000     1.620000     3.500000     2.150000     1.700000
# 50%       4.000000     2.250000     3.800000     3.200000     2.370000
# 75%       5.000000     3.300000     4.500000     5.250000     3.480000
# max      15.000000    19.000000    13.000000    29.000000    22.000000
#
#               MaxD         MaxA         AvgH         AvgD         AvgA
# count  2480.000000  2480.000000  2480.000000  2480.000000  2480.000000
# mean      4.526363     4.998319     2.930980     4.280133     4.549113
# std       1.564885     5.060761     2.120203     1.343313     4.086985
# min       3.100000     1.170000     1.070000     2.970000     1.150000
# 25%       3.650000     2.250000     1.650000     3.490000     2.180000
# 50%       4.000000     3.310000     2.290000     3.820000     3.185000
# 75%       4.750000     5.600000     3.322500     4.532500     5.222500
# max      17.000000    50.000000    18.090000    12.850000    37.570000

# %%
simpleData = data[["HomeTeam", "AwayTeam", "FTHG", "FTAG"]]
simpleData
# Out:
#            HomeTeam          AwayTeam  FTHG  FTAG
# 0         Liverpool           Norwich     4     1
# 1          West Ham          Man City     0     5
# 2       Bournemouth  Sheffield United     1     1
# 3           Burnley       Southampton     3     0
# 4    Crystal Palace           Everton     0     0
# ..              ...               ...   ...   ...
# 195         Everton         Brentford     2     4
# 196       Newcastle    Crystal Palace     2     0
# 197       Tottenham        Sunderland     1     1
# 198          Fulham         Liverpool     2     2
# 199        Man City           Chelsea     1     1
#
# [2480 rows x 4 columns]

# %%
uniqueTeams = data["HomeTeam"].unique()

# %%
teamsIndex = {}
for i in range(len(uniqueTeams)):
    teamsIndex[uniqueTeams[i]] = i
teamsIndex
# Out:
# {'Liverpool': 0,
#  'West Ham': 1,
#  'Bournemouth': 2,
#  'Burnley': 3,
#  'Crystal Palace': 4,
#  'Watford': 5,
#  'Tottenham': 6,
#  'Leicester': 7,
#  'Newcastle': 8,
#  'Man United': 9,
#  'Arsenal': 10,
#  'Aston Villa': 11,
#  'Brighton': 12,
#  'Everton': 13,
#  'Norwich': 14,
#  'Southampton': 15,
#  'Man City': 16,
#  'Sheffield United': 17,
#  'Chelsea': 18,
#  'Wolves': 19,
#  'Fulham': 20,
#  'West Brom': 21,
#  'Leeds': 22,
#  'Brentford': 23,
#  "Nott'm Forest": 24,
#  'Luton': 25,
#  'Ipswich': 26,
#  'Sunderland': 27}

# %%
from scipy.optimize import minimize
def phi(t):
    return np.exp(-0.012*t)

def logLikelihood(parameters, data):
    numTeams = int((len(parameters) - 2) // 2)
    
    attackStrengths = np.array(parameters[0:numTeams])
    defenceStrengths = np.array(parameters[numTeams:numTeams*2])
    
    homeAdv = parameters[-2]
    rho = parameters[-1]
    t = data.index[-1]
    ll = 0

    for tk, row in data.iterrows():
        i = teamsIndex.get(row["HomeTeam"])
        j = teamsIndex.get(row["AwayTeam"])
        x = int(row["FTHG"])
        y = int(row["FTAG"])

        lamd = attackStrengths[i] * defenceStrengths[j] * homeAdv
        mu = attackStrengths[j] * defenceStrengths[i]

        ll += (np.log(Match.tauFunc(lamd, mu, rho, x, y) + 1e-7) - lamd + x*np.log(lamd) - mu + y*np.log(mu)) * phi(t - tk)
    
    return -ll

# %%
from scipy.optimize import minimize
np.random.seed(1008)
def getNewEstimates(results: pd.DataFrame):
    rng = np.random.default_rng(123)
    init_att = rng.uniform(0.8, 1.3, size=len(uniqueTeams))
    init_def = rng.uniform(0.8, 1.3, size=len(uniqueTeams))
    init_home = 1.1
    init_rho = 0.0

    init = np.concatenate([init_att, init_def, [init_home, init_rho]])

    bounds = [(1e-6, None)] * (2*len(uniqueTeams)) + [(1e-6, None), (-0.99, 0.99)]

    result = minimize(
        logLikelihood,
        init,
        args=(results,),
        bounds=bounds,
        options={'maxiter': 10000, 'disp': True},
    )
    return result.x

# %%
import csv
len(data["HomeTeam"])
# Out:
# 2480

# %%
currentEstimates = getNewEstimates(simpleData)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.25831D+03    |proj g|=  1.57805D+03
#
# At iterate    1    f=  8.23839D+03    |proj g|=  9.26846D+01
#
# At iterate    2    f=  7.68898D+03    |proj g|=  1.86519D+02
#
# At iterate    3    f=  7.50237D+03    |proj g|=  1.94828D+02
#
# At iterate    4    f=  7.33810D+03    |proj g|=  4.11622D+02
#
# At iterate    5    f=  7.16491D+03    |proj g|=  9.10181D+01
#
# At iterate    6    f=  7.11410D+03    |proj g|=  4.86581D+01
#
# At iterate    7    f=  7.08505D+03    |proj g|=  7.58319D+01
#
# At iterate    8    f=  7.07584D+03    |proj g|=  1.83531D+01
#
# At iterate    9    f=  7.07305D+03    |proj g|=  1.64884D+01
#
# At iterate   10    f=  7.07120D+03    |proj g|=  1.44964D+01
#
# At iterate   11    f=  7.06912D+03    |proj g|=  9.75451D+00
#
# At iterate   12    f=  7.06781D+03    |proj g|=  6.47406D+00
#
# At iterate   13    f=  7.06667D+03    |proj g|=  4.58031D+00
#
# At iterate   14    f=  7.06645D+03    |proj g|=  1.66406D+01
#
# At iterate   15    f=  7.06637D+03    |proj g|=  2.61634D+00
#
# At iterate   16    f=  7.06632D+03    |proj g|=  2.44727D+00
#
# At iterate   17    f=  7.06622D+03    |proj g|=  1.87265D+00
#
# At iterate   18    f=  7.06609D+03    |proj g|=  2.27783D+00
#
# At iterate   19    f=  7.06592D+03    |proj g|=  3.24490D+00
#
# At iterate   20    f=  7.06573D+03    |proj g|=  8.76998D+00
#
# At iterate   21    f=  7.06562D+03    |proj g|=  2.78815D+00
#
# At iterate   22    f=  7.06550D+03    |proj g|=  2.08393D+00
#
# At iterate   23    f=  7.06548D+03    |proj g|=  9.82080D-01
#
# At iterate   24    f=  7.06547D+03    |proj g|=  8.84120D-01
#
# At iterate   25    f=  7.06545D+03    |proj g|=  9.98907D-01
#
# At iterate   26    f=  7.06544D+03    |proj g|=  1.18102D+00
#
# At iterate   27    f=  7.06544D+03    |proj g|=  1.98370D+00
#
# At iterate   28    f=  7.06544D+03    |proj g|=  1.12095D+00
#
# At iterate   29    f=  7.06543D+03    |proj g|=  6.02722D-01
#
# At iterate   30    f=  7.06543D+03    |proj g|=  5.42877D-01
#
# At iterate   31    f=  7.06542D+03    |proj g|=  1.26256D+00
#
# At iterate   32    f=  7.06542D+03    |proj g|=  1.18090D+00
#
# At iterate   33    f=  7.06541D+03    |proj g|=  9.82043D-01
#
# At iterate   34    f=  7.06541D+03    |proj g|=  4.29645D-01
#
# At iterate   35    f=  7.06541D+03    |proj g|=  3.85262D-01
#
# At iterate   36    f=  7.06540D+03    |proj g|=  7.66431D-01
#
# At iterate   37    f=  7.06540D+03    |proj g|=  3.38787D-01
#
# At iterate   38    f=  7.06540D+03    |proj g|=  2.41471D-01
#
# At iterate   39    f=  7.06540D+03    |proj g|=  1.75896D-01
#
# At iterate   40    f=  7.06540D+03    |proj g|=  1.02045D-01
#
# At iterate   41    f=  7.06540D+03    |proj g|=  5.30235D-02
#
# At iterate   42    f=  7.06540D+03    |proj g|=  4.36557D-02
#
# At iterate   43    f=  7.06540D+03    |proj g|=  8.51287D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     43     48     55     0     0   8.513D-02   7.065D+03
#   F =   7065.4038286418790
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
teamsLookup = {v: k for k, v in teamsIndex.items()}

fig, ax = plt.subplots()
ax.scatter(currentEstimates[0:28], currentEstimates[28:56])

# %%
home = "Man United"
away = "Bournemouth"
match = Match(currentEstimates[teamsIndex.get(home)], currentEstimates[teamsIndex.get(home) + 28], currentEstimates[teamsIndex.get(away)], currentEstimates[teamsIndex.get(away) + 28], currentEstimates[-2], currentEstimates[-1], 8)

# %%
homeTeams = ["Man City", "Brentford", "Bournemouth", "Everton", "Crystal Palace", "Fulham", "Newcastle", "Burnley"]
awayTeams = ["Brighton", "Sunderland", "Tottenham", "Wolves", "Aston Villa", "Chelsea", "Leeds", "Man United"]
for i in range(len(homeTeams)):
    match = Match(currentEstimates[teamsIndex.get(homeTeams[i])], currentEstimates[teamsIndex.get(homeTeams[i]) + 28], currentEstimates[teamsIndex.get(awayTeams[i])], currentEstimates[teamsIndex.get(awayTeams[i]) + 28], currentEstimates[-2], currentEstimates[-1], 8)
    probs = 1 / np.array(match.getOutcomeProbs())
    print(f"{homeTeams[i]}  {probs[0]}  -  {probs[1]}  -  {probs[2]}  {awayTeams[i]}")
# Out:
# Man City  1.294924036295939  -  6.948931116389549  -  11.92649880095924  Brighton
# Brentford  2.8153434684684666  -  2.9393903765321405  -  3.2830269205515417  Sunderland
# Bournemouth  3.179429262240321  -  4.3273002814462  -  2.200766334148114  Tottenham
# Everton  2.291321982630216  -  3.4596567711577038  -  3.642659380692166  Wolves
# Crystal Palace  2.5016763410728573  -  3.7927018928043075  -  2.9708521511766093  Aston Villa
# Fulham  3.3588994154404355  -  4.009825940482874  -  2.208012190543495  Chelsea
# Newcastle  1.6553800723315308  -  5.072336315575438  -  5.031160187566178  Leeds
# Burnley  4.312370600414076  -  3.9366066858290334  -  1.9452108099694536  Man United

# %%
homeTeams = ["Man City", "Brentford", "Bournemouth", "Everton", "Crystal Palace", "Fulham", "Newcastle", "Burnley"]
awayTeams = ["Brighton", "Sunderland", "Tottenham", "Wolves", "Aston Villa", "Chelsea", "Leeds", "Man United"]
for i in range(len(homeTeams)):
    match = Match(currentEstimates[teamsIndex.get(homeTeams[i])], currentEstimates[teamsIndex.get(homeTeams[i]) + 28], currentEstimates[teamsIndex.get(awayTeams[i])], currentEstimates[teamsIndex.get(awayTeams[i]) + 28], currentEstimates[-2], currentEstimates[-1], 8)
    over2_5 = 0
    under2_5 = 0
    scores = match.getScoreMatrix()
    for x in range(len(scores)):
        for y in range(len(scores[x])):
            if (x + y) > 2:
                over2_5 += scores[x][y]
            else:
                under2_5 += scores[x][y]
    print(f"{homeTeams[i]} vs {awayTeams[i]}: Under @ {1 / under2_5}, Over @ {1 / over2_5}")
# Out:
# Man City vs Brighton: Under @ 2.8223193258235684, Over @ 1.5487512456402583
# Brentford vs Sunderland: Under @ 1.3115917318084043, Over @ 4.209327777076228
# Bournemouth vs Tottenham: Under @ 2.571902825672963, Over @ 1.6361716409358062
# Everton vs Wolves: Under @ 1.5643147684605752, Over @ 2.772060658146433
# Crystal Palace vs Aston Villa: Under @ 1.8894347965758984, Over @ 2.1243095096456184
# Fulham vs Chelsea: Under @ 2.0741224794622846, Over @ 1.9309925256387974
# Newcastle vs Leeds: Under @ 2.9816231399031854, Over @ 1.5046368201215377
# Burnley vs Man United: Under @ 1.8294905577514267, Over @ 2.2055592322964928

# %%
estimatesAtTimeT = []
for i in range(200, len(data["HomeTeam"]), 10):
    estimatesAtTimeT.append(getNewEstimates(simpleData.head(n=i)))

with open("estimatesOvernight.csv", "w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(estimatesAtTimeT)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.12115D+02    |proj g|=  2.24056D+01
#
# At iterate    1    f=  2.03894D+02    |proj g|=  6.71192D+00
#
# At iterate    2    f=  1.98120D+02    |proj g|=  5.38861D+00
#
# At iterate    3    f=  1.84575D+02    |proj g|=  6.92619D+00
#
# At iterate    4    f=  1.84068D+02    |proj g|=  1.07320D+00
#
# At iterate    5    f=  1.84008D+02    |proj g|=  8.50798D-01
#
# At iterate    6    f=  1.83886D+02    |proj g|=  4.47267D-01
#
# At iterate    7    f=  1.83882D+02    |proj g|=  4.96377D-01
#
# At iterate    8    f=  1.83878D+02    |proj g|=  8.63253D-02
#
# At iterate    9    f=  1.83878D+02    |proj g|=  4.93145D-02
#
# At iterate   10    f=  1.83878D+02    |proj g|=  2.83478D-02
#
# At iterate   11    f=  1.83877D+02    |proj g|=  1.00698D-02
#
# At iterate   12    f=  1.83877D+02    |proj g|=  2.07962D-02
#
# At iterate   13    f=  1.83877D+02    |proj g|=  1.59446D-03
#
# At iterate   14    f=  1.83877D+02    |proj g|=  1.41540D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     14     16     24     0     0   1.415D-03   1.839D+02
#   F =   183.87748078122780
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.17659D+02    |proj g|=  2.42487D+01
#
# At iterate    1    f=  2.09595D+02    |proj g|=  7.31782D+00
#
# At iterate    2    f=  2.04147D+02    |proj g|=  5.46342D+00
#
# At iterate    3    f=  1.90388D+02    |proj g|=  5.23835D+00
#
# At iterate    4    f=  1.89955D+02    |proj g|=  7.70794D-01
#
# At iterate    5    f=  1.89867D+02    |proj g|=  1.17856D+00
#
# At iterate    6    f=  1.89804D+02    |proj g|=  8.62585D-01
#
# At iterate    7    f=  1.89786D+02    |proj g|=  4.01153D-01
#
# At iterate    8    f=  1.89784D+02    |proj g|=  1.89030D-01
#
# At iterate    9    f=  1.89783D+02    |proj g|=  4.32919D-02
#
# At iterate   10    f=  1.89783D+02    |proj g|=  2.93340D-02
#
# At iterate   11    f=  1.89783D+02    |proj g|=  1.99691D-02
#
# At iterate   12    f=  1.89783D+02    |proj g|=  1.76385D-02
#
# At iterate   13    f=  1.89783D+02    |proj g|=  2.56364D-03
#
# At iterate   14    f=  1.89783D+02    |proj g|=  1.63425D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     14     17     21     0     0   1.634D-03   1.898D+02
#   F =   189.78269641725976
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.22457D+02    |proj g|=  2.20027D+01
#
# At iterate    1    f=  2.20573D+02    |proj g|=  2.61273D+00
#
# At iterate    2    f=  2.05153D+02    |proj g|=  5.14957D+00
#
# At iterate    3    f=  1.97257D+02    |proj g|=  9.93034D+00
#
# At iterate    4    f=  1.92586D+02    |proj g|=  1.08803D+01
#
# At iterate    5    f=  1.90528D+02    |proj g|=  9.15362D+00
#
# At iterate    6    f=  1.89959D+02    |proj g|=  1.17575D+00
#
# At iterate    7    f=  1.89775D+02    |proj g|=  4.94147D-01
#
# At iterate    8    f=  1.89710D+02    |proj g|=  4.84931D-01
#
# At iterate    9    f=  1.89698D+02    |proj g|=  2.53647D-01
#
# At iterate   10    f=  1.89695D+02    |proj g|=  2.27880D-01
#
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.38673D+02    |proj g|=  2.52987D+01
#
# At iterate    1    f=  2.29636D+02    |proj g|=  7.06480D+00
#
# At iterate    2    f=  2.22708D+02    |proj g|=  5.42710D+00
#
# At iterate    3    f=  2.07277D+02    |proj g|=  1.10643D+01
#
# At iterate    4    f=  2.04837D+02    |proj g|=  1.17158D+00
#
# At iterate    5    f=  2.04473D+02    |proj g|=  5.63369D-01
#
# At iterate    6    f=  2.04417D+02    |proj g|=  4.14786D-01
#
# At iterate    7    f=  2.04370D+02    |proj g|=  4.82032D-01
#
# At iterate    8    f=  2.04364D+02    |proj g|=  1.28654D-01
#
# At iterate    9    f=  2.04363D+02    |proj g|=  2.46814D-02
#
# At iterate   10    f=  2.04363D+02    |proj g|=  2.44569D-02
#
# At iterate   11    f=  2.04363D+02    |proj g|=  1.25340D-02
#
# At iterate   12    f=  2.04363D+02    |proj g|=  3.63229D-03
#
# At iterate   13    f=  2.04363D+02    |proj g|=  1.58309D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     13     15     23     0     0   1.583D-02   2.044D+02
#   F =   204.36319470575998
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.42309D+02    |proj g|=  2.47496D+01
#
# At iterate    1    f=  2.33808D+02    |proj g|=  6.55760D+00
#
# At iterate    2    f=  2.26896D+02    |proj g|=  5.15725D+00
#
# At iterate    3    f=  2.11245D+02    |proj g|=  1.12006D+01
#
# At iterate    4    f=  2.09360D+02    |proj g|=  1.20774D+00
#
# At iterate    5    f=  2.08595D+02    |proj g|=  6.52565D-01
#
# At iterate    6    f=  2.08470D+02    |proj g|=  1.09236D+00
#
# At iterate    7    f=  2.08415D+02    |proj g|=  2.83583D-01
#
# At iterate    8    f=  2.08393D+02    |proj g|=  1.18541D-01
#
# At iterate    9    f=  2.08390D+02    |proj g|=  7.01704D-02
#
# At iterate   10    f=  2.08390D+02    |proj g|=  2.46331D-02
#
# At iterate   11    f=  2.08390D+02    |proj g|=  4.27463D-03
#
# At iterate   12    f=  2.08390D+02    |proj g|=  3.22302D-03
#
# At iterate   13    f=  2.08390D+02    |proj g|=  6.38636D-03
#
# At iterate   14    f=  2.08390D+02    |proj g|=  1.05160D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     14     17     24     0     0   1.052D-03   2.084D+02
#   F =   208.38980574281786
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.44359D+02    |proj g|=  3.08246D+01
#
# At iterate    1    f=  2.35472D+02    |proj g|=  7.02056D+00
#
# At iterate    2    f=  2.29506D+02    |proj g|=  5.65742D+00
#
# At iterate    3    f=  2.14106D+02    |proj g|=  1.46596D+01
#
# At iterate    4    f=  2.11823D+02    |proj g|=  1.21762D+00
#
# At iterate    5    f=  2.10731D+02    |proj g|=  8.75599D-01
#
# At iterate    6    f=  2.10521D+02    |proj g|=  8.10971D-01
#
# At iterate    7    f=  2.10452D+02    |proj g|=  3.93391D-01
#
# At iterate    8    f=  2.10436D+02    |proj g|=  1.15176D-01
#
# At iterate    9    f=  2.10434D+02    |proj g|=  3.37508D-02
#
# At iterate   10    f=  2.10434D+02    |proj g|=  1.09395D-02
#
# At iterate   11    f=  2.10434D+02    |proj g|=  3.13776D-03
#
# At iterate   12    f=  2.10434D+02    |proj g|=  1.72719D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     12     14     22     0     0   1.727D-02   2.104D+02
#   F =   210.43428835872231
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.47642D+02    |proj g|=  3.08180D+01
#
# At iterate    1    f=  2.39709D+02    |proj g|=  5.68894D+00
#
# At iterate    2    f=  2.34672D+02    |proj g|=  4.58171D+00
#
# At iterate    3    f=  2.21855D+02    |proj g|=  7.81268D+00
#
# At iterate    4    f=  2.19820D+02    |proj g|=  1.22859D+00
#
# At iterate    5    f=  2.18767D+02    |proj g|=  9.40152D-01
#
# At iterate    6    f=  2.18712D+02    |proj g|=  5.84700D-01
#
# At iterate    7    f=  2.18675D+02    |proj g|=  4.60139D-01
#
# At iterate    8    f=  2.18657D+02    |proj g|=  2.20859D-01
#
# At iterate    9    f=  2.18655D+02    |proj g|=  4.83880D-02
#
# At iterate   10    f=  2.18655D+02    |proj g|=  6.34941D-03
#
# At iterate   11    f=  2.18655D+02    |proj g|=  5.29496D-03
#
# At iterate   12    f=  2.18655D+02    |proj g|=  7.91545D-03
#
# At iterate   13    f=  2.18655D+02    |proj g|=  2.00373D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     13     16     23     0     0   2.004D-03   2.187D+02
#   F =   218.65526721958457
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.50397D+02    |proj g|=  3.27351D+01
#
# At iterate    1    f=  2.42236D+02    |proj g|=  6.12824D+00
#
# At iterate    2    f=  2.36939D+02    |proj g|=  4.75529D+00
#
# At iterate    3    f=  2.22460D+02    |proj g|=  5.60659D+00
#
# At iterate    4    f=  2.21016D+02    |proj g|=  1.23328D+00
#
# At iterate    5    f=  2.19806D+02    |proj g|=  9.55521D-01
#
# At iterate    6    f=  2.19731D+02    |proj g|=  5.57108D-01
#
# At iterate    7    f=  2.19702D+02    |proj g|=  3.63673D-01
#
# At iterate    8    f=  2.19685D+02    |proj g|=  2.95901D-01
#
# At iterate    9    f=  2.19682D+02    |proj g|=  8.25366D-02
#
# At iterate   10    f=  2.19681D+02    |proj g|=  6.87237D-03
#
# At iterate   11    f=  2.19681D+02    |proj g|=  4.12399D-03
#
# At iterate   12    f=  2.19681D+02    |proj g|=  5.34897D-03
#
# At iterate   13    f=  2.19681D+02    |proj g|=  1.09708D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     13     16     23     0     0   1.097D-03   2.197D+02
#   F =   219.68133087362318
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.51789D+02    |proj g|=  3.12802D+01
#
# At iterate    1    f=  2.43981D+02    |proj g|=  5.86108D+00
#
# At iterate    2    f=  2.38532D+02    |proj g|=  4.96858D+00
#
# At iterate    3    f=  2.25387D+02    |proj g|=  6.41366D+00
#
# At iterate    4    f=  2.22257D+02    |proj g|=  1.20077D+00
#
# At iterate    5    f=  2.21825D+02    |proj g|=  1.00159D+00
#
# At iterate    6    f=  2.21778D+02    |proj g|=  4.38558D-01
#
# At iterate    7    f=  2.21738D+02    |proj g|=  3.91492D-01
#
# At iterate    8    f=  2.21723D+02    |proj g|=  2.29275D-01
#
# At iterate    9    f=  2.21720D+02    |proj g|=  5.02183D-02
#
# At iterate   10    f=  2.21720D+02    |proj g|=  9.08926D-03
#
# At iterate   11    f=  2.21720D+02    |proj g|=  7.70513D-03
#
# At iterate   12    f=  2.21720D+02    |proj g|=  4.76632D-03
#
# At iterate   13    f=  2.21720D+02    |proj g|=  5.07043D-03
#
# At iterate   14    f=  2.21720D+02    |proj g|=  1.16813D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     14     17     25     0     0   1.168D-03   2.217D+02
#   F =   221.71982624069193
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.59574D+02    |proj g|=  3.48058D+01
#
# At iterate    1    f=  2.50279D+02    |proj g|=  6.04990D+00
#
# At iterate    2    f=  2.43740D+02    |proj g|=  5.19352D+00
#
# At iterate    3    f=  2.25353D+02    |proj g|=  1.04755D+01
#
# At iterate    4    f=  2.24482D+02    |proj g|=  1.20437D+00
#
# At iterate    5    f=  2.23902D+02    |proj g|=  8.99504D-01
#
# At iterate    6    f=  2.23775D+02    |proj g|=  1.70585D+00
#
# At iterate    7    f=  2.23734D+02    |proj g|=  3.63815D-01
#
# At iterate    8    f=  2.23727D+02    |proj g|=  2.46473D-01
#
# At iterate    9    f=  2.23721D+02    |proj g|=  1.11817D-01
#
# At iterate   10    f=  2.23721D+02    |proj g|=  1.10603D-01
#
# At iterate   11    f=  2.23721D+02    |proj g|=  8.30482D-03
#
# At iterate   12    f=  2.23721D+02    |proj g|=  5.70424D-03
#
# At iterate   13    f=  2.23721D+02    |proj g|=  2.13646D-02
#
# At iterate   14    f=  2.23721D+02    |proj g|=  5.34044D-03
#
# At iterate   15    f=  2.23721D+02    |proj g|=  1.06581D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     15     17     28     0     0   1.066D-03   2.237D+02
#   F =   223.72073772422397
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.63010D+02    |proj g|=  3.83499D+01
#
# At iterate    1    f=  2.52200D+02    |proj g|=  7.78730D+00
#
# At iterate    2    f=  2.45203D+02    |proj g|=  6.54425D+00
#
# At iterate    3    f=  2.26400D+02    |proj g|=  2.47839D+01
#
# At iterate    4    f=  2.25401D+02    |proj g|=  1.69297D+00
#
# At iterate    5    f=  2.24128D+02    |proj g|=  1.31452D+00
#
# At iterate    6    f=  2.23366D+02    |proj g|=  1.06126D+00
#
# At iterate    7    f=  2.23334D+02    |proj g|=  1.40612D+00
#
# At iterate    8    f=  2.23290D+02    |proj g|=  4.82675D-01
#
# At iterate    9    f=  2.23280D+02    |proj g|=  3.48314D-01
#
# At iterate   10    f=  2.23270D+02    |proj g|=  1.38513D-01
#
# At iterate   11    f=  2.23269D+02    |proj g|=  4.72596D-02
#
# At iterate   12    f=  2.23269D+02    |proj g|=  1.29575D-02
#
# At iterate   13    f=  2.23269D+02    |proj g|=  5.27507D-03
#
# At iterate   14    f=  2.23269D+02    |proj g|=  2.79954D-03
#
# At iterate   15    f=  2.23269D+02    |proj g|=  1.60867D-03
#
# At iterate   16    f=  2.23269D+02    |proj g|=  5.94014D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     16     20     28     0     0   5.940D-04   2.233D+02
#   F =   223.26861274871507
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64562D+02    |proj g|=  3.75876D+01
#
# At iterate    1    f=  2.54416D+02    |proj g|=  7.16943D+00
#
# At iterate    2    f=  2.47819D+02    |proj g|=  6.02445D+00
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_4393/2450435370.py:25: RuntimeWarning: invalid value encountered in log
#   ll += (np.log(Match.tauFunc(lamd, mu, rho, x, y) + 1e-7) - lamd + x*np.log(lamd) - mu + y*np.log(mu)) * phi(t - tk)
# At iterate    3    f=  2.31089D+02    |proj g|=  3.13194D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97047D+03    |proj g|=  4.24105D+02
#
# At iterate    1    f=  2.85219D+03    |proj g|=  1.05036D+02
#
# At iterate    2    f=  2.76797D+03    |proj g|=  8.58233D+01
#
# At iterate    3    f=  2.57048D+03    |proj g|=  3.01875D+02
#
# At iterate    4    f=  2.52756D+03    |proj g|=  1.58390D+01
#
# At iterate    5    f=  2.51142D+03    |proj g|=  1.08253D+01
#
# At iterate    6    f=  2.50305D+03    |proj g|=  6.07997D+00
#
# At iterate    7    f=  2.50182D+03    |proj g|=  3.68409D+01
#
# At iterate    8    f=  2.50079D+03    |proj g|=  4.65607D+00
#
# At iterate    9    f=  2.50061D+03    |proj g|=  4.59845D+00
#
# At iterate   10    f=  2.49959D+03    |proj g|=  8.76325D+00
#
# At iterate   11    f=  2.49861D+03    |proj g|=  1.12806D+01
#
# At iterate   12    f=  2.49597D+03    |proj g|=  1.46909D+01
#
# At iterate   13    f=  2.49524D+03    |proj g|=  9.54292D+00
#
# At iterate   14    f=  2.49392D+03    |proj g|=  2.29618D+00
#
# At iterate   15    f=  2.49351D+03    |proj g|=  2.27698D+00
#
# At iterate   16    f=  2.49340D+03    |proj g|=  1.61326D+00
#
# At iterate   17    f=  2.49337D+03    |proj g|=  9.07316D-01
#
# At iterate   18    f=  2.49335D+03    |proj g|=  8.46694D-01
#
# At iterate   19    f=  2.49334D+03    |proj g|=  8.52151D-01
#
# At iterate   20    f=  2.49332D+03    |proj g|=  1.08191D+00
#
# At iterate   21    f=  2.49327D+03    |proj g|=  1.08402D+00
#
# At iterate   22    f=  2.49316D+03    |proj g|=  1.91772D+00
#
# At iterate   23    f=  2.49301D+03    |proj g|=  1.42250D+00
#
# At iterate   24    f=  2.49296D+03    |proj g|=  4.31214D+00
#
# At iterate   25    f=  2.49287D+03    |proj g|=  2.24122D+00
#
# At iterate   26    f=  2.49284D+03    |proj g|=  2.19802D+00
#
# At iterate   27    f=  2.49284D+03    |proj g|=  2.62162D-01
#
# At iterate   28    f=  2.49283D+03    |proj g|=  2.54295D-01
#
# At iterate   29    f=  2.49283D+03    |proj g|=  2.38333D-01
#
# At iterate   30    f=  2.49283D+03    |proj g|=  8.61701D-01
#
# At iterate   31    f=  2.49283D+03    |proj g|=  3.05590D-01
#
# At iterate   32    f=  2.49283D+03    |proj g|=  2.93358D-01
#
# At iterate   33    f=  2.49282D+03    |proj g|=  3.79214D-01
#
# At iterate   34    f=  2.49282D+03    |proj g|=  6.85395D-01
#
# At iterate   35    f=  2.49281D+03    |proj g|=  7.16364D-01
#
# At iterate   36    f=  2.49281D+03    |proj g|=  2.24532D+00
#
# At iterate   37    f=  2.49280D+03    |proj g|=  3.92083D-01
#
# At iterate   38    f=  2.49280D+03    |proj g|=  2.56796D-01
#
# At iterate   39    f=  2.49280D+03    |proj g|=  4.40741D-01
#
# At iterate   40    f=  2.49280D+03    |proj g|=  1.60662D-01
#
# At iterate   41    f=  2.49280D+03    |proj g|=  1.64619D-01
#
# At iterate   42    f=  2.49280D+03    |proj g|=  3.32329D-01
#
# At iterate   43    f=  2.49280D+03    |proj g|=  4.74392D-01
#
# At iterate   44    f=  2.49279D+03    |proj g|=  9.02997D-01
#
# At iterate   45    f=  2.49279D+03    |proj g|=  4.65661D-01
#
# At iterate   46    f=  2.49279D+03    |proj g|=  2.80443D-01
#
#
# At iterate   36    f=  2.35469D+03    |proj g|=  2.17005D-01
#
# At iterate   37    f=  2.35469D+03    |proj g|=  2.64754D-01
#
# At iterate   38    f=  2.35469D+03    |proj g|=  2.20098D-01
#
# At iterate   39    f=  2.35469D+03    |proj g|=  7.07996D-01
#
# At iterate   40    f=  2.35469D+03    |proj g|=  1.10936D+00
#
# At iterate   41    f=  2.35468D+03    |proj g|=  1.30376D+00
#
# At iterate   42    f=  2.35468D+03    |proj g|=  1.27379D+00
#
# At iterate   43    f=  2.35468D+03    |proj g|=  3.90446D-01
#
# At iterate   44    f=  2.35468D+03    |proj g|=  1.00499D-01
#
# At iterate   45    f=  2.35468D+03    |proj g|=  4.66616D-01
#
# At iterate   46    f=  2.35468D+03    |proj g|=  7.45786D-01
#
# At iterate   47    f=  2.35468D+03    |proj g|=  9.81254D-01
#
# At iterate   48    f=  2.35467D+03    |proj g|=  1.30908D+00
#
# At iterate   49    f=  2.35467D+03    |proj g|=  4.32374D-01
#
# At iterate   50    f=  2.35467D+03    |proj g|=  1.68802D-01
#
# At iterate   51    f=  2.35467D+03    |proj g|=  1.54023D-01
#
# At iterate   52    f=  2.35467D+03    |proj g|=  2.55977D-01
#
# At iterate   53    f=  2.35467D+03    |proj g|=  3.58068D-01
#
# At iterate   54    f=  2.35467D+03    |proj g|=  5.00631D-01
#
# At iterate   55    f=  2.35467D+03    |proj g|=  3.26190D-01
#
# At iterate   56    f=  2.35467D+03    |proj g|=  7.27596D-02
#
# At iterate   57    f=  2.35467D+03    |proj g|=  6.25732D-02
#
# At iterate   58    f=  2.35467D+03    |proj g|=  1.08594D-01
#
# At iterate   59    f=  2.35467D+03    |proj g|=  2.11730D-01
#
# At iterate   60    f=  2.35467D+03    |proj g|=  3.03316D-01
#
# At iterate   61    f=  2.35467D+03    |proj g|=  7.39101D-01
#
# At iterate   62    f=  2.35467D+03    |proj g|=  3.40742D-01
#
# At iterate   63    f=  2.35467D+03    |proj g|=  2.55977D-01
#
# At iterate   64    f=  2.35467D+03    |proj g|=  1.32104D-01
#
# At iterate   65    f=  2.35467D+03    |proj g|=  1.72622D-01
#
# At iterate   66    f=  2.35467D+03    |proj g|=  7.73980D-02
#
# At iterate   67    f=  2.35467D+03    |proj g|=  3.17414D-02
#
# At iterate   68    f=  2.35467D+03    |proj g|=  3.13321D-02
#
# At iterate   69    f=  2.35467D+03    |proj g|=  4.18822D-02
#
# At iterate   70    f=  2.35467D+03    |proj g|=  6.15273D-02
#
# At iterate   71    f=  2.35467D+03    |proj g|=  7.77618D-02
#
# At iterate   72    f=  2.35467D+03    |proj g|=  1.02955D-01
#
# At iterate   73    f=  2.35467D+03    |proj g|=  8.20364D-02
#
# At iterate   74    f=  2.35467D+03    |proj g|=  7.00311D-02
#
# At iterate   75    f=  2.35467D+03    |proj g|=  2.64663D-02
#
# At iterate   76    f=  2.35467D+03    |proj g|=  1.57343D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     76     83     89     0     0   1.573D-02   2.355D+03
#   F =   2354.6663128831165
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2
#
# At iterate   27    f=  1.12353D+04    |proj g|=  2.70084D+00
#
# At iterate   28    f=  1.12352D+04    |proj g|=  3.07391D+00
#
# At iterate   29    f=  1.12352D+04    |proj g|=  3.01716D+00
#
# At iterate   30    f=  1.12352D+04    |proj g|=  1.10576D+00
#
# At iterate   31    f=  1.12352D+04    |proj g|=  6.02813D-01
#
# At iterate   32    f=  1.12352D+04    |proj g|=  9.32414D-01
#
# At iterate   33    f=  1.12352D+04    |proj g|=  4.66935D-01
#
# At iterate   34    f=  1.12352D+04    |proj g|=  2.43381D-01
#
# At iterate   35    f=  1.12352D+04    |proj g|=  2.22462D-01
#
# At iterate   36    f=  1.12352D+04    |proj g|=  7.79983D-01
#
# At iterate   37    f=  1.12352D+04    |proj g|=  2.77942D-01
#
# At iterate   38    f=  1.12352D+04    |proj g|=  2.16824D-01
#
# At iterate   39    f=  1.12352D+04    |proj g|=  2.68665D-01
#
# At iterate   40    f=  1.12352D+04    |proj g|=  4.06544D-01
#
# At iterate   41    f=  1.12352D+04    |proj g|=  7.89078D-01
#
# At iterate   42    f=  1.12352D+04    |proj g|=  4.06544D-01
#
# At iterate   43    f=  1.12352D+04    |proj g|=  2.28465D-01
#
# At iterate   44    f=  1.12352D+04    |proj g|=  5.61158D-01
#
# At iterate   45    f=  1.12352D+04    |proj g|=  5.45515D-01
#
# At iterate   46    f=  1.12352D+04    |proj g|=  6.07179D-01
#
# At iterate   47    f=  1.12352D+04    |proj g|=  1.17593D+00
#
# At iterate   48    f=  1.12352D+04    |proj g|=  1.05138D-01
#
# At iterate   49    f=  1.12352D+04    |proj g|=  1.11322D-01
#
# At iterate   50    f=  1.12352D+04    |proj g|=  2.03909D-01
#
# At iterate   51    f=  1.12352D+04    |proj g|=  1.13323D-01
#
# At iterate   52    f=  1.12352D+04    |proj g|=  2.53749D-01
#
# At iterate   53    f=  1.12352D+04    |proj g|=  4.10182D-01
#
# At iterate   54    f=  1.12352D+04    |proj g|=  6.23913D-02
#
# At iterate   55    f=  1.12352D+04    |proj g|=  4.03816D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     55     63     67     0     0   4.038D-02   1.124D+04
#   F =   11235.218139858820
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.21083D+04    |proj g|=  2.17762D+03
#
# At iterate    1    f=  1.15376D+04    |proj g|=  3.37241D+02
#
# At iterate    2    f=  1.13657D+04    |proj g|=  2.90124D+02
#
# At iterate    3    f=  1.06820D+04    |proj g|=  1.79962D+02
#
# At iterate    4    f=  1.06224D+04    |proj g|=  1.72511D+02
#
# At iterate    5    f=  1.05970D+04    |proj g|=  7.98123D+01
#
# At iterate    6    f=  1.05682D+04    |proj g|=  3.35333D+01
#
# At iterate    7    f=  1.05591D+04    |proj g|=  2.77583D+01
#
# At iterate    8    f=  1.05532D+04    |proj g|=  2.07268D+01
#
# At iterate    9    f=  1.05503D+04    |proj g|=  2.73616D+01
#
# At iterate   10    f=  1.05477D+04    |proj g|=  2.43996D+01
#
# At iterate   11    f=  1.05472D+04    |proj g|=  1.70432D+01
#
# At iterate   12    f=  1.05469D+04    |proj g|=  6.88051D+00
#
# At iterate   13    f=  1.05468D+04    |proj g|=  2.18915D+00
#
# At iterate   14    f=  1.05468D+04    |proj g|=  1.97651D+00
#
# At iterate   15    f=  1.05467D+04    |proj g|=  1.17637D+00
#
# At iterate   16    f=  1.05467D+04    |proj g|=  1.17594D+00
#
# At iterate   17    f=  1.05467D+04    |proj g|=  1.23837D+00
#
# At iterate   18    f=  1.05467D+04    |proj g|=  1.09800D+00
#
# At iterate   19    f=  1.05466D+04    |proj g|=  8.14725D+00
#
# At iterate   20    f=  1.05466D+04    |proj g|=  3.35476D+00
#
# At iterate   21    f=  1.05465D+04    |proj g|=  4.02179D+00
#
# At iterate   22    f=  1.05464D+04    |proj g|=  3.61433D+00
#
# At iterate   23    f=  1.05463D+04    |proj g|=  2.05440D+01
#
# At iterate   24    f=  1.05462D+04    |proj g|=  2.39343D+00
#
# At iterate   25    f=  1.05462D+04    |proj g|=  1.94686D+00
#
# At iterate   26    f=  1.05461D+04    |proj g|=  1.74186D+00
#
# At iterate   27    f=  1.05461D+04    |proj g|=  3.55885D+00
#
# At iterate   28    f=  1.05461D+04    |proj g|=  4.37449D+00
#
# At iterate   29    f=  1.05461D+04    |proj g|=  2.89001D+00
#
# At iterate   30    f=  1.05461D+04    |proj g|=  1.76933D+00
#
# At iterate   31    f=  1.05461D+04    |proj g|=  4.73665D-01
#
# At iterate   32    f=  1.05461D+04    |proj g|=  5.46243D-01
#
# At iterate   33    f=  1.05461D+04    |proj g|=  9.52423D-01
#
# At iterate   34    f=  1.05461D+04    |proj g|=  1.02555D+00
#
# At iterate   35    f=  1.05461D+04    |proj g|=  1.12886D+00
#
# At iterate   36    f=  1.05461D+04    |proj g|=  6.12999D-01
#
# At iterate   37    f=  1.05461D+04    |proj g|=  6.93399D-01
#
# At iterate   38    f=  1.05461D+04    |proj g|=  6.27915D-01
#
# At iterate   39    f=  1.05461D+04    |proj g|=  3.80351D-01
#
# At iterate   40    f=  1.05461D+04    |proj g|=  3.20688D-01
#
# At iterate   41    f=  1.05461D+04    |proj g|=  6.01540D-01
#
# At iterate   42    f=  1.05461D+04    |proj g|=  6.42096D-01
#
# At iterate   43    f=  1.05461D+04    |proj g|=  9.74978D-01
#
# At iterate   44    f=  1.05461D+04    |proj g|=  1.49339D-01
#
# At iterate   45    f=  1.05461D+04    |proj g|=  1.16779D-01
#
# At iterate   46    f=  1.05461D+04    |proj g|=  1.43700D-01
#
# At iterate   47    f=  1.05461D+04    |proj g|=  2.02090D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     47     54     59     0     0   2.021D-01   1.055D+04
#   F =   10546.086980816795
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.13647D+04    |proj g|=  2.04153D+03
#
# At iterate    1    f=  1.08299D+04    |proj g|=  3.16038D+02
#
# At iterate    2    f=  1.06687D+04    |proj g|=  2.71910D+02
#
# At iterate    3    f=  1.00289D+04    |proj g|=  1.69559D+02
#
# At iterate    4    f=  9.97158D+03    |proj g|=  1.65431D+02
#
# At iterate    5    f=  9.94794D+03    |proj g|=  7.49651D+01
#
# At iterate    6    f=  9.92080D+03    |proj g|=  3.16577D+01
#
# At iterate    7    f=  9.91207D+03    |proj g|=  2.62067D+01
#
# At iterate    8    f=  9.90661D+03    |proj g|=  1.98816D+01
#
# At iterate    9    f=  9.90384D+03    |proj g|=  2.81680D+01
#
# At iterate   10    f=  9.90128D+03    |proj g|=  2.42360D+01
#
# At iterate   11    f=  9.90073D+03    |proj g|=  1.60579D+01
#
# At iterate   12    f=  9.90040D+03    |proj g|=  7.85039D+00
#
# At iterate   13    f=  9.90035D+03    |proj g|=  2.18170D+00
#
# At iterate   14    f=  9.90030D+03    |proj g|=  2.08202D+00
#
# At iterate   15    f=  9.90024D+03    |proj g|=  1.17534D+00
#
# At iterate   16    f=  9.90021D+03    |proj g|=  1.17568D+00
#
# At iterate   17    f=  9.90018D+03    |proj g|=  1.17548D+00
#
# At iterate   18    f=  9.90015D+03    |proj g|=  1.29930D+00
#
# At iterate   19    f=  9.90011D+03    |proj g|=  3.80587D+00
#
# At iterate   20    f=  9.90005D+03    |proj g|=  2.95313D+00
#
# At iterate   21    f=  9.89996D+03    |proj g|=  2.68728D+01
#
# At iterate   22    f=  9.89985D+03    |proj g|=  9.32669D+00
#
# At iterate   23    f=  9.89975D+03    |proj g|=  2.80652D+00
#
# At iterate   24    f=  9.89971D+03    |proj g|=  2.61498D+00
#
# At iterate   25    f=  9.89962D+03    |proj g|=  1.83900D+00
#
# At iterate   26    f=  9.89959D+03    |proj g|=  3.81315D+00
#
# At iterate   27    f=  9.89958D+03    |proj g|=  1.46920D+00
#
# At iterate   28    f=  9.89958D+03    |proj g|=  1.84791D+00
#
# At iterate   29    f=  9.89957D+03    |proj g|=  9.94398D-01
#
# At iterate   30    f=  9.89957D+03    |proj g|=  1.17614D+00
#
# At iterate   31    f=  9.89956D+03    |proj g|=  6.54836D-01
#
# At iterate   32    f=  9.89956D+03    |proj g|=  3.94539D-01
#
# At iterate   33    f=  9.89956D+03    |proj g|=  3.40879D-01
#
# At iterate   34    f=  9.89956D+03    |proj g|=  9.84801D-01
#
# At iterate   35    f=  9.89956D+03    |proj g|=  5.24597D-01
#
# At iterate   36    f=  9.89956D+03    |proj g|=  2.37014D-01
#
# At iterate   37    f=  9.89956D+03    |proj g|=  2.28465D-01
#
# At iterate   38    f=  9.89956D+03    |proj g|=  2.45382D-01
#
# At iterate   39    f=  9.89956D+03    |proj g|=  1.12323D+00
#
# At iterate   40    f=  9.89956D+03    |proj g|=  5.60249D-01
#
# At iterate   41    f=  9.89956D+03    |proj g|=  2.05546D-01
#
# At iterate   42    f=  9.89956D+03    |proj g|=  4.71300D-01
#
# At iterate   43    f=  9.89956D+03    |proj g|=  7.88714D-01
#
# At iterate   44    f=  9.89956D+03    |proj g|=  3.55976D-01
#
# At iterate   45    f=  9.89956D+03    |proj g|=  2.70484D-01
#
# At iterate   46    f=  9.89956D+03    |proj g|=  5.18230D-01
#
# At iterate   47    f=  9.89956D+03    |proj g|=  3.68163D-01
#
# At iterate   48    f=  9.89956D+03    |proj g|=  1.32604D-01
#
# At iterate   49    f=  9.89956D+03    |proj g|=  6.91216D-02
#
# At iterate   50    f=  9.89956D+03    |proj g|=  3.85626D-02
#
# At iterate   51    f=  9.89956D+03    |proj g|=  1.33696D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     51     60     63     0     0   1.337D-01   9.900D+03
#   F =   9899.5564244455945
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           58     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.06677D+04    |proj g|=  1.91827D+03
#
# At iterate    1    f=  1.01652D+04    |proj g|=  2.95298D+02
#
# At iterate    2    f=  1.00142D+04    |proj g|=  2.54118D+02
#
# At iterate    3    f=  9.41793D+03    |proj g|=  1.57866D+02
#
# At iterate    4    f=  9.36191D+03    |proj g|=  1.59122D+02
#
# At iterate    5    f=  9.34006D+03    |proj g|=  7.07498D+01
#
# At iterate    6    f=  9.31444D+03    |proj g|=  3.00070D+01
#
# At iterate    7    f=  9.30602D+03    |proj g|=  2.48316D+01
#
# At iterate    8    f=  9.30095D+03    |proj g|=  1.91825D+01
#
# At iterate    9    f=  9.29831D+03    |proj g|=  2.93820D+01
#
# At iterate   10    f=  9.29582D+03    |proj g|=  2.47093D+01
#
# At iterate   11    f=  9.29512D+03    |proj g|=  2.21216D+01
#
# At iterate   12    f=  9.29478D+03    |proj g|=  1.16343D+01
#
# At iterate   13    f=  9.29472D+03    |proj g|=  2.28774D+00
#
# At iterate   14    f=  9.29468D+03    |proj g|=  2.05546D+00
#
# At iterate   15    f=  9.29462D+03    |proj g|=  1.37206D+00
#
# At iterate   16    f=  9.29456D+03    |proj g|=  1.18998D+00
#
# At iterate   17    f=  9.29454D+03    |proj g|=  2.41307D+00
#
# At iterate   18    f=  9.29451D+03    |proj g|=  1.26493D+00
#
# At iterate   19    f=  9.29449D+03    |proj g|=  1.08485D+00
#
# At iterate   20    f=  9.29444D+03    |proj g|=  1.41936D+00
#
# At iterate   21    f=  9.29437D+03    |proj g|=  2.43363D+00
#
# At iterate   22    f=  9.29423D+03    |proj g|=  2.75522D+00
#
# At iterate   23    f=  9.29420D+03    |proj g|=  1.14511D+01
#
# At iterate   24    f=  9.29410D+03    |proj g|=  2.17824D+00
#
# At iterate   25    f=  9.29405D+03    |proj g|=  1.70639D+00
#
# At iterate   26    f=  9.29403D+03    |proj g|=  1.42390D+00
#
# At iterate   27    f=  9.29402D+03    |proj g|=  3.42679D+00
#
# At iterate   28    f=  9.29401D+03    |proj g|=  7.36145D-01
#
# At iterate   29    f=  9.29400D+03    |proj g|=  5.76256D-01
#
# At iterate   30    f=  9.29400D+03    |proj g|=  1.17658D+00
#
# At iterate   31    f=  9.29400D+03    |proj g|=  2.95950D-01
#
# At iterate   32    f=  9.29400D+03    |proj g|=  2.44472D-01
#
# At iterate   33    f=  9.29400D+03    |proj g|=  1.57706D-01
#
# At iterate   34    f=  9.29400D+03    |proj g|=  3.81078D-01
#
# At iterate   35    f=  9.29400D+03    |proj g|=  2.27919D-01
#
# At iterate   36    f=  9.29400D+03    |proj g|=  1.54614D-01
#
# At iterate   37    f=  9.29400D+03    |proj g|=  1.29330D-01
#
# At iterate   38    f=  9.29400D+03    |proj g|=  1.24783D-01
#
# At iterate   39    f=  9.29400D+03    |proj g|=  3.26509D-01
#
# At iterate   40    f=  9.29400D+03    |proj g|=  1.13687D-01
#
# At iterate   41    f=  9.29400D+03    |proj g|=  1.70257D-01
#
# At iterate   42    f=  9.29400D+03    |proj g|=  1.82263D-01
#
# At iterate   43    f=  9.29400D+03    |proj g|=  4.21824D-01
#
# At iterate   44    f=  9.29400D+03    |proj g|=  9.44056D-02
#
# At iterate   45    f=  9.29400D+03    |proj g|=  8.62201D-02
#
# At iterate   46    f=  9.29400D+03    |proj g|=  1.46974D-01
#
# At iterate   47    f=  9.29400D+03    |proj g|=  6.34827D-01
#
# At iterate   48    f=  9.29400D+03    |proj g|=  2.58478D-01
#
# At iterate   49    f=  9.29400D+03    |proj g|=  6.60293D-02
#
# At iterate   50    f=  9.29400D+03    |proj g|=  7.31234D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    58     50     57     62     0     0   7.312D-02   9.294D+03
#   F =   9293.9960873071923
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
estimatesAtTimeT = []

with open("estimatesOvernight.csv", newline="") as my_csv:
    csvReader = csv.reader(my_csv)
    for row in csvReader:
        estimatesAtTimeT.append([float(x) for x in row])

# %%
len(estimatesAtTimeT[0])
# Out:
# 58

# %%
strengthsOverTime = [[row[i] for row in estimatesAtTimeT] for i in range(len(estimatesAtTimeT[0]))]

# %%
teamsLookup = {v: k for k, v in teamsIndex.items()}

fig, ax = plt.subplots()
for i in range(28):
    ax.plot(strengthsOverTime[28+i], label=f"{teamsLookup.get(i)}")

ax.legend(prop={'size': 6})

# %%
len(strengthsOverTime[0])
# Out:
# 218

# %%
simpleDataNew = simpleData.head(n=2380)

# %%
teamStrengths = [[] for i in range(58)]

for i in range(len(simpleDataNew["AwayTeam"])):
    if i < 200:
        for j in range(58):
            teamStrengths[j].append(0)
    else:
        for j in range(58):
            teamStrengths[j].append(strengthsOverTime[j][(i-200) // 10])

# %%
len(simpleData["HomeTeam"])
# Out:
# 2470

# %%
len(teamStrengths[0])
# Out:
# 2380

# %%
data.describe()
# Out:
#               FTHG         FTAG           HS           AS          HST  \
# count  2470.000000  2470.000000  2470.000000  2470.000000  2470.000000
# mean      1.555061     1.319433    13.814575    11.634818     4.796356
# std       1.323681     1.222671     5.668623     5.194344     2.589552
# min       0.000000     0.000000     1.000000     1.000000     0.000000
# 25%       1.000000     0.000000    10.000000     8.000000     3.000000
# 50%       1.000000     1.000000    13.000000    11.000000     5.000000
# 75%       2.000000     2.000000    17.000000    15.000000     6.000000
# max       9.000000     9.000000    36.000000    37.000000    16.000000
#
#                AST        B365H        B365D        B365A         MaxH  \
# count  2470.000000  2470.000000  2470.000000  2470.000000  2470.000000
# mean      4.111336     2.897972     4.253652     4.432012     3.105142
# std       2.393658     2.068710     1.341948     3.754306     2.426004
# min       0.000000     1.060000     2.800000     1.140000     1.090000
# 25%       2.000000     1.620000     3.500000     2.150000     1.700000
# 50%       4.000000     2.250000     3.800000     3.200000     2.370000
# 75%       5.000000     3.300000     4.500000     5.250000     3.480000
# max      15.000000    19.000000    13.000000    29.000000    22.000000
#
#               MaxD         MaxA         AvgH         AvgD         AvgA
# count  2470.000000  2470.000000  2470.000000  2470.000000  2470.000000
# mean      4.528453     5.002696     2.932425     4.281955     4.552591
# std       1.567321     5.069464     2.122633     1.345427     4.093789
# min       3.100000     1.170000     1.070000     2.970000     1.150000
# 25%       3.650000     2.250000     1.650000     3.490000     2.180000
# 50%       4.000000     3.310000     2.290000     3.820000     3.185000
# 75%       4.750000     5.600000     3.327500     4.540000     5.230000
# max      17.000000    50.000000    18.090000    12.850000    37.570000

# %%
attack = teamStrengths[0:28]
defence = teamStrengths[28:56]
homeAdvantage = teamStrengths[-2]
rho = teamStrengths[-1]

# %%
len(homeAdvantage)
# Out:
# 2380

# %%
data = data.head(n=2380)

# %%
home_idx = data["HomeTeam"].map(teamsIndex).to_numpy()
away_idx = data["AwayTeam"].map(teamsIndex).to_numpy()

# %%
print(attack[away_idx[900]][910])
# Out:
# 0.8847161072823861

# %%
t = np.arange(len(data["HomeTeam"]))

# %%
t
# Out:
# array([   0,    1,    2, ..., 2377, 2378, 2379])

# %%
homeAttacks = []
homeDefences = []
awayAttacks = []
awayDefences = []

for i in range(len(data["HomeTeam"])):
    homeAttacks.append(attack[home_idx[i]][i])
    homeDefences.append(defence[home_idx[i]][i])
    awayAttacks.append(attack[away_idx[i]][i])
    awayDefences.append(defence[away_idx[i]][i])

homeProbs = []
drawProbs = []
awayProbs = []

for i in range(len(data["HomeTeam"])):
    thisMatch = Match(homeAttacks[i], homeDefences[i], awayAttacks[i], awayDefences[i], homeAdvantage[i], rho[i], 8)
    outcomes = thisMatch.getOutcomeProbs()
    homeProbs.append(outcomes[0])
    drawProbs.append(outcomes[1])
    awayProbs.append(outcomes[2])



data["attackH"]  = homeAttacks
data["defenceH"] = homeDefences
data["attackA"]  = awayAttacks
data["defenceA"] = awayDefences
data["rho"] = rho
data["homeAdv"] = homeAdvantage
data["homeProb"] = homeProbs
data["drawProb"] = drawProbs
data["awayProb"] = awayProbs
data["FairHomeOdds"] = 1 / data["homeProb"]
data["FairDrawOdds"] = 1 / data["drawProb"]
data["FairAwayOdds"] = 1 / data["awayProb"]

# %%
data.tail()
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 95  01/11/2025   Tottenham      Chelsea     0     1   A   3  15    1    9
# 96  01/11/2025   Liverpool  Aston Villa     2     0   H  16  10    4    3
# 97  02/11/2025    West Ham    Newcastle     3     1   H  15  12    9    4
# 98  02/11/2025    Man City  Bournemouth     3     1   H  15   8    8    5
# 99  03/11/2025  Sunderland      Everton     1     1   D  17   8    3    2
#
#     ...   attackA  defenceA       rho   homeAdv  homeProb  drawProb  awayProb  \
# 95  ...  1.394149  0.940286  0.004966  1.176475  0.407536  0.232125  0.360339
# 96  ...  1.196041  1.015676  0.004966  1.176475  0.638734  0.197506  0.163760
# 97  ...  1.388267  1.053781  0.004966  1.176475  0.356811  0.234933  0.408256
# 98  ...  1.069273  1.175001  0.004966  1.176475  0.816666  0.120382  0.062952
# 99  ...  0.911645  1.020615  0.004966  1.176475  0.551004  0.291733  0.157263
#
#     FairHomeOdds  FairDrawOdds  FairAwayOdds
# 95      2.453769      4.308031      2.775165
# 96      1.565597      5.063140      6.106490
# 97      2.802602      4.256537      2.449444
# 98      1.224491      8.306867     15.885201
# 99      1.814869      3.427788      6.358792
#
# [5 rows x 31 columns]

# %%
bettingFrame = data.tail(n=2180)
bettingFrame["HomeWin"] = np.where(bettingFrame["FTR"] == "H", 1, 0)
bettingFrame["Draw"] = np.where(bettingFrame["FTR"] == "D", 1, 0)
bettingFrame["AwayWin"] = np.where(bettingFrame["FTR"] == "A", 1, 0)
bettingFrame.head()
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/3958715411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["HomeWin"] = np.where(bettingFrame["FTR"] == "H", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/3958715411.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Draw"] = np.where(bettingFrame["FTR"] == "D", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/3958715411.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["AwayWin"] = np.where(bettingFrame["FTR"] == "A", 1, 0)
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 200  01/01/2020      Burnley  Aston Villa     1     2   A  20  11    1    6
# 201  01/01/2020    Newcastle    Leicester     0     3   A   5  17    2   10
# 202  01/01/2020  Southampton    Tottenham     1     0   H  12  11    3    5
# 203  01/01/2020      Watford       Wolves     2     1   H   9  16    3    4
# 204  01/01/2020     Man City      Everton     2     1   H  16   7    7    2
#
#      ...   homeAdv  homeProb  drawProb  awayProb  FairHomeOdds  FairDrawOdds  \
# 200  ...  1.095947  0.401036  0.267411  0.331553      2.493541      3.739565
# 201  ...  1.095947  0.132853  0.201389  0.665758      7.527110      4.965526
# 202  ...  1.095947  0.237765  0.209617  0.552617      4.205827      4.770599
# 203  ...  1.095947  0.198164  0.284994  0.516842      5.046331      3.508843
# 204  ...  1.095947  0.742369  0.153005  0.104625      1.347038      6.535719
#
#      FairAwayOdds  HomeWin  Draw  AwayWin
# 200      3.016109        0     0        1
# 201      1.502047        0     0        1
# 202      1.809570        1     0        0
# 203      1.934827        1     0        0
# 204      9.557922        1     0        0
#
# [5 rows x 34 columns]

# %%
bettingFrame["ValueRatioHome"] = bettingFrame["MaxH"] * bettingFrame["homeProb"]
bettingFrame["ValueRatioDraw"] = bettingFrame["MaxD"] * bettingFrame["drawProb"]
bettingFrame["ValueRatioAway"] = bettingFrame["MaxA"] * bettingFrame["awayProb"]
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/551312071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioHome"] = bettingFrame["MaxH"] * bettingFrame["homeProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/551312071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioDraw"] = bettingFrame["MaxD"] * bettingFrame["drawProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/551312071.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioAway"] = bettingFrame["MaxA"] * bettingFrame["awayProb"]

# %%
bettingFrame.head()
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 200  01/01/2020      Burnley  Aston Villa     1     2   A  20  11    1    6
# 201  01/01/2020    Newcastle    Leicester     0     3   A   5  17    2   10
# 202  01/01/2020  Southampton    Tottenham     1     0   H  12  11    3    5
# 203  01/01/2020      Watford       Wolves     2     1   H   9  16    3    4
# 204  01/01/2020     Man City      Everton     2     1   H  16   7    7    2
#
#      ...  awayProb  FairHomeOdds  FairDrawOdds  FairAwayOdds  HomeWin  Draw  \
# 200  ...  0.331553      2.493541      3.739565      3.016109        0     0
# 201  ...  0.665758      7.527110      4.965526      1.502047        0     0
# 202  ...  0.552617      4.205827      4.770599      1.809570        1     0
# 203  ...  0.516842      5.046331      3.508843      1.934827        1     0
# 204  ...  0.104625      1.347038      6.535719      9.557922        1     0
#
#      AwayWin  ValueRatioHome  ValueRatioDraw  ValueRatioAway
# 200        1        0.741917        1.069643        1.525144
# 201        1        0.777191        0.815624        1.138447
# 202        0        0.834557        0.813315        1.243389
# 203        0        0.653940        0.988930        1.250758
# 204        0        0.965080        1.014425        1.255503
#
# [5 rows x 37 columns]

# %%
bettingFrame["HomeBet"] = np.where(bettingFrame['ValueRatioHome'] > 1.1, 1, 0)
bettingFrame["AwayBet"] = np.where(bettingFrame['ValueRatioAway'] > 1.1, 1, 0)
bettingFrame["DrawBet"] = np.where(bettingFrame['ValueRatioDraw'] > 1.1, 1, 0)
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/195808689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["HomeBet"] = np.where(bettingFrame['ValueRatioHome'] > 1.1, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/195808689.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["AwayBet"] = np.where(bettingFrame['ValueRatioAway'] > 1.1, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/195808689.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["DrawBet"] = np.where(bettingFrame['ValueRatioDraw'] > 1.1, 1, 0)

# %%
#bettingFrame = bettingFrame[[
 #   "Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR",
  #  "B365H", "B365D", "B365A", "MaxH", "MaxD", "MaxA", 'attackH', 'defenceH', 'attackA', 'defenceA', 'rho',
   # 'homeAdv', 'homeProb', 'drawProb', 'awayProb', 'FairHomeOdds',
    #'FairDrawOdds', 'FairAwayOdds', 'HomeWin', 'Draw', 'AwayWin', 'HomeBet',
    #"DrawBet", 'AwayBet'
#]]

# %%
bettingFrame.tail()
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 95  01/11/2025   Tottenham      Chelsea     0     1   A   3  15    1    9
# 96  01/11/2025   Liverpool  Aston Villa     2     0   H  16  10    4    3
# 97  02/11/2025    West Ham    Newcastle     3     1   H  15  12    9    4
# 98  02/11/2025    Man City  Bournemouth     3     1   H  15   8    8    5
# 99  03/11/2025  Sunderland      Everton     1     1   D  17   8    3    2
#
#     ...  FairAwayOdds  HomeWin  Draw  AwayWin  ValueRatioHome  ValueRatioDraw  \
# 95  ...      2.775165        0     0        1        1.141102        0.835649
# 96  ...      6.106490        1     0        0        1.066686        0.888776
# 97  ...      2.449444        1     0        0        1.962462        1.033704
# 98  ...     15.885201        1     0        0        1.224999        0.589873
# 99  ...      6.358792        0     1        0        1.542811        0.933547
#
#     ValueRatioAway  HomeBet  AwayBet  DrawBet
# 95        0.936881        1        0        0
# 96        0.818801        0        0        0
# 97        0.681787        1        0        0
# 98        0.409186        1        0        0
# 99        0.440335        1        0        0
#
# [5 rows x 40 columns]

# %%
bettingFrame["Profit"] = bettingFrame["HomeWin"] * bettingFrame["HomeBet"] * bettingFrame["MaxH"] + bettingFrame["AwayWin"] * bettingFrame["AwayBet"] * bettingFrame["MaxA"] - (bettingFrame["HomeBet"] + bettingFrame["AwayBet"])
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_11915/1858422377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Profit"] = bettingFrame["HomeWin"] * bettingFrame["HomeBet"] * bettingFrame["MaxH"] + bettingFrame["AwayWin"] * bettingFrame["AwayBet"] * bettingFrame["MaxA"] - (bettingFrame["HomeBet"] + bettingFrame["AwayBet"])

# %%
bettingFrame.head()
# Out:
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 200  01/01/2020      Burnley  Aston Villa     1     2   A  20  11    1    6
# 201  01/01/2020    Newcastle    Leicester     0     3   A   5  17    2   10
# 202  01/01/2020  Southampton    Tottenham     1     0   H  12  11    3    5
# 203  01/01/2020      Watford       Wolves     2     1   H   9  16    3    4
# 204  01/01/2020     Man City      Everton     2     1   H  16   7    7    2
#
#      ...  HomeWin  Draw  AwayWin  ValueRatioHome  ValueRatioDraw  \
# 200  ...        0     0        1        0.741917        1.069643
# 201  ...        0     0        1        0.777191        0.815624
# 202  ...        1     0        0        0.834557        0.813315
# 203  ...        1     0        0        0.653940        0.988930
# 204  ...        1     0        0        0.965080        1.014425
#
#      ValueRatioAway  HomeBet  AwayBet  DrawBet  Profit
# 200        1.525144        0        1        0    3.60
# 201        1.138447        0        1        0    0.71
# 202        1.243389        0        1        0   -1.00
# 203        1.250758        0        1        0   -1.00
# 204        1.255503        0        1        0   -1.00
#
# [5 rows x 41 columns]

# %%
fig, ax = plt.subplots()
ax.plot(bettingFrame["Date"], bettingFrame["Profit"].cumsum())

# %%
home_profits = bettingFrame.loc[bettingFrame["HomeBet"] > 0, "Profit"]
draw_profits = bettingFrame.loc[bettingFrame["DrawBet"] > 0, "Profit"]
away_profits = bettingFrame.loc[bettingFrame["AwayBet"] > 0, "Profit"]

# %%
sum(home_profits)
# Out:
# -53.28

# %%
sum(away_profits)
# Out:
# -22.350000000000005

# %%
sum(draw_profits)
# Out:
# -30.530000000000005

# %%
plt.hist(home_profits, bins=30, alpha=0.5, label="Home Bets")
plt.hist(draw_profits, bins=30, alpha=0.5, label="Draw Bets")
plt.hist(away_profits, bins=30, alpha=0.5, label="Away Bets")

plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.title("Profit Distribution by Bet Type")
plt.legend()
plt.show()

# %%
bettingFrame.HomeBet.sum() + bettingFrame.DrawBet.sum() + bettingFrame.AwayBet.sum()
# Out:
# 2149

# %%
bettingFrame["Profit"].sum()
# Out:
# -73.63000000000002

# %%
-94.17 / 3243
# Out:
# -0.029037927844588345

# %%
cleanProfits = [x for x in bettingFrame.Profit if x!=0]

# %%
np.var(cleanProfits)
# Out:
# 4.017505919364514

# %%
np.mean(cleanProfits)
# Out:
# -0.0461340852130326

# %%
import csv


with open("profitsMLE.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(cleanProfits)
