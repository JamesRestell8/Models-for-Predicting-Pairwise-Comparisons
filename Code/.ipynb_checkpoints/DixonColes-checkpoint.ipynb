# %%
import math
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from DCmatch import Match

# %%
teams = [i for i in range(10)]
attackStrengths = [0.1*(i+1) for i in range(10)]
defenceStrengths = [0.1*(10-i) for i in range(10)]
homeAdvantage = 1.2

homeAdv = 1.2
rho = 0.5
maxGoals = 7

# simulate 100 games between the teams at random
for i in range(100):
    currentTeams = random.sample(teams, 2)
    homeTeam = currentTeams[0]
    awayTeam = currentTeams[1]
    # simulate match
    match = Match(attackStrengths[homeTeam], defenceStrengths[homeTeam],
                  attackStrengths[awayTeam], defenceStrengths[awayTeam],
                 homeAdv, rho, maxGoals)
    print(match.simulateResult())
    # add match to match DataFrame
    # use Dixon Coles to estimate parameters
# Out:
# 0.0838121978067442
# [0, 0]
# 0.10093479851294196
# [0, 0]
# 0.2700416705939297
# [0, 0]
# 0.7174081276756322
# [0, 1]
# 0.5109219451723463
# [0, 1]
# 0.9501826343838737
# [0, 3]
# 0.9734987664828549
# [1, 2]
# 0.9858366750587078
# [2, 0]
# 0.2678785893991973
# [0, 0]
# 0.28280519891889366
# [0, 0]
# 0.4734140527439923
# [0, 0]
# 0.27569358119637166
# [0, 0]
# 0.822292428765177
# [1, 0]
# 0.044774341082526314
# [0, 0]
# 0.8194043746579039
# [0, 2]
# 0.10092695700148424
# [0, 0]
# 0.0025067625748061984
# [0, 0]
# 0.61547645727558
# [0, 1]
# 0.1934548670275935
# [0, 0]
# 0.24973557026326654
# [0, 0]
# 0.2349514024142083
# [0, 0]
# 0.3981754613262084
# [0, 0]
# 0.3988201779404764
# [0, 0]
# 0.6894129259456094
# [1, 0]
# 0.47053326022836706
# [0, 0]
# 0.15872060329620152
# [0, 0]
# 0.10170712743221444
# [0, 0]
# 0.9335067989274654
# [2, 0]
# 0.16363214912725688
# [0, 0]
# 0.2568080320516041
# [0, 0]
# 0.2919855831617606
# [0, 0]
# 0.7087838862596206
# [1, 0]
# 0.898765643350608
# [2, 0]
# 0.861934510386437
# [1, 0]
# 0.06245399936111973
# [0, 0]
# 0.8117922368061733
# [2, 0]
# 0.6857556048087473
# [0, 1]
# 0.14873770974182
# [0, 0]
# 0.658281339640751
# [0, 1]
# 0.1444028856093924
# [0, 0]
# 0.3994439225803924
# [0, 0]
# 0.6319984334660214
# [0, 1]
# 0.9793800169464367
# [0, 4]
# 0.05607790600083429
# [0, 0]
# 0.024378906587755322
# [0, 0]
# 0.25217085932772654
# [0, 0]
# 0.9962324319762673
# [1, 2]
# 0.4705834026813558
# [0, 0]
# 0.19314863444746133
# [0, 0]
# 0.6666693822206705
# [0, 1]
# 0.8013365096184853
# [1, 0]
# 0.7938120090479448
# [2, 0]
# 0.8585455738530395
# [1, 0]
# 0.4198703623498454
# [0, 0]
# 0.5813094325403064
# [0, 2]
# 0.9071262250481992
# [1, 0]
# 0.34515732825484047
# [0, 0]
# 0.494171318890975
# [1, 0]
# 0.4154065248126161
# [0, 0]
# 0.24664950673414454
# [0, 0]
# 0.5797560443617397
# [0, 1]
# 0.34580558408102224
# [0, 0]
# 0.4418394276358162
# [0, 0]
# 0.7182152391554781
# [0, 1]
# 0.5478892528847924
# [0, 0]
# 0.6613698218115194
# [0, 1]
# 0.23532893876671523
# [0, 0]
# 0.7695917159472268
# [1, 0]
# 0.9035006063062286
# [3, 0]
# 0.9168008199791696
# [2, 0]
# 0.552200265988788
# [0, 1]
# 0.47136906882710194
# [0, 0]
# 0.5414997022720117
# [0, 1]
# 0.13566316562620073
# [0, 0]
# 0.7465585739720558
# [1, 0]
# 0.7602253722317767
# [0, 1]
# 0.9740350699141728
# [1, 3]
# 0.10310694429893552
# [0, 0]
# 0.10570492413460075
# [0, 0]
# 0.3044148505415112
# [0, 0]
# 0.17599064758006555
# [0, 0]
# 0.21905292464635773
# [0, 0]
# 0.405314573033175
# [0, 0]
# 0.8418641698957954
# [1, 0]
# 0.7633360664396366
# [1, 0]
# 0.2056023472977131
# [0, 0]
# 0.8753114012697734
# [1, 1]
# 0.4059326135695839
# [0, 0]
# 0.15646169222666662
# [0, 0]
# 0.9143783138621091
# [2, 0]
# 0.5738824539669932
# [0, 1]
# 0.5353431014536453
# [0, 1]
# 0.47756176522058713
# [0, 1]
# 0.9741707210109376
# [2, 1]
# 0.47316413948164593
# [0, 0]
# 0.25780350577417355
# [0, 0]
# 0.647440299164232
# [0, 1]
# 0.7904556644845051
# [0, 2]
# 0.7273922824177089
# [0, 1]
# 0.7039564913140205
# [1, 0]

# %%
homeAttack = 1.2
homeDefence = 0.8
awayAttack = 0.7
awayDefence = 0.7

homeAdv = 1.2
rho = 0.5

match = Match(homeAttack, homeDefence, awayAttack, awayDefence, homeAdv, rho, maxGoals)

# %%
match.getScoreMatrix()
# Out:
# [[0.14963, 0.17557, 0.03269, 0.0061, 0.00085, 0.0001, 1e-05],
#  [0.26897, 0.05884, 0.03295, 0.00615, 0.00086, 0.0001, 1e-05],
#  [0.10591, 0.05931, 0.01661, 0.0031, 0.00043, 5e-05, 0.0],
#  [0.03558, 0.01993, 0.00558, 0.00104, 0.00015, 2e-05, 0.0],
#  [0.00897, 0.00502, 0.00141, 0.00026, 4e-05, 0.0, 0.0],
#  [0.00181, 0.00101, 0.00028, 5e-05, 1e-05, 0.0, 0.0],
#  [0.0003, 0.00017, 5e-05, 1e-05, 0.0, 0.0, 0.0]]

# %%
match.probJoint(0,0)
# Out:
# 0.14962546196097393

# %%
match.tau(0, 0)
# Out:
# 0.71776

# %%
premVSchamp = Match(1.38, 0.68, 1.07, 0.86, 1.2, 0.5, 7)
homeGoals = []
awayGoals = []

for i in range(100):
    result = premVSchamp.simulateResult()
    homeGoals.append(result[0])
    awayGoals.append(result[1])

fig, ax = plt.subplots(2, 1)
ax[0].hist(homeGoals)
ax[1].hist(awayGoals)
# Out:
# 0.9748336423032301
# 0.9875338429876432
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 6
#       3 awayGoals = []
#       5 for i in range(100):
# ----> 6     result = premVSchamp.simulateResult()
#       7     homeGoals.append(result[0])
#       8     awayGoals.append(result[1])
#
# File ~/Documents/Bristol/Year 3/Models for predicting pairwise comparisons/Code/DCmatch.py:61, in Match.simulateResult(self)
#      59 j = 0
#      60 while total < value:
# ---> 61     total += scorelineProbs[i][j]
#      62     if total > value:
#      63         return [i, j]
#
# IndexError: list index out of range

# %%
sums = [sum(match.getScoreMatrix()[i]) for i in range(len(match.getScoreMatrix()))]
sums
# Out:
# [0.36495,
#  0.36788,
#  0.18541000000000002,
#  0.0623,
#  0.015700000000000002,
#  0.00316,
#  0.00053]
