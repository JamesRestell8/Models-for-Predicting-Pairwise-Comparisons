# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import random
import csv
from DCmatch import Match

from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
folder = os.fsencode("seasons/bettingSeasons")
dataframes = []
for file in sorted(os.listdir(folder)):
    filename = os.fsdecode(file)
    if filename.endswith(".csv"):
        print(filename)
        df = pd.read_csv("seasons/bettingSeasons/" + filename)
        dataframes.append(df)

data = pd.concat(dataframes, axis=0)
# Out:
# 1920-Copy1.csv
# 2021-Copy1.csv
# 2122-Copy1.csv
# 2223-Copy1.csv
# 2324-Copy1.csv
# 2425-Copy1.csv
# E0 (1).csv

# %%
data = data[[
    "Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR", "HS", "AS", "HST", "AST", 
    "B365H", "B365D", "B365A", "MaxH", "MaxD", "MaxA", "AvgH", "AvgD", "AvgA", "Max>2.5", "Max<2.5"
]]

# %%
data = data.head(n=2380)

# %%
uniqueTeams = data["HomeTeam"].unique()
teamsIndex = {}
for i in range(len(uniqueTeams)):
    teamsIndex[uniqueTeams[i]] = i
teamsIndex
# Out:
# {'Liverpool': 0,
#  'West Ham': 1,
#  'Bournemouth': 2,
#  'Burnley': 3,
#  'Crystal Palace': 4,
#  'Watford': 5,
#  'Tottenham': 6,
#  'Leicester': 7,
#  'Newcastle': 8,
#  'Man United': 9,
#  'Arsenal': 10,
#  'Aston Villa': 11,
#  'Brighton': 12,
#  'Everton': 13,
#  'Norwich': 14,
#  'Southampton': 15,
#  'Man City': 16,
#  'Sheffield United': 17,
#  'Chelsea': 18,
#  'Wolves': 19,
#  'Fulham': 20,
#  'West Brom': 21,
#  'Leeds': 22,
#  'Brentford': 23,
#  "Nott'm Forest": 24,
#  'Luton': 25,
#  'Ipswich': 26,
#  'Sunderland': 27}

# %%
estimatesAtTimeT = []

with open("estimatesOvernight.csv", newline="") as my_csv:
    csvReader = csv.reader(my_csv)
    for row in csvReader:
        estimatesAtTimeT.append([float(x) for x in row])
        
strengthsOverTime = [[row[i] for row in estimatesAtTimeT] for i in range(len(estimatesAtTimeT[0]))]

# %%
teamStrengths = [[] for i in range(58)]

for i in range(len(data["AwayTeam"])):
    if i < 200:
        for j in range(58):
            teamStrengths[j].append(0)
    else:
        for j in range(58):
            teamStrengths[j].append(strengthsOverTime[j][(i-200) // 10])

# %%
attack = teamStrengths[0:28]
defence = teamStrengths[28:56]
homeAdvantage = teamStrengths[-2]
rho = teamStrengths[-1]
len(homeAdvantage)
# Out:
# 2380

# %%
home_idx = data["HomeTeam"].map(teamsIndex).to_numpy()
away_idx = data["AwayTeam"].map(teamsIndex).to_numpy()

# %%
homeAttacks = []
homeDefences = []
awayAttacks = []
awayDefences = []

for i in range(len(data["HomeTeam"])):
    homeAttacks.append(attack[home_idx[i]][i])
    homeDefences.append(defence[home_idx[i]][i])
    awayAttacks.append(attack[away_idx[i]][i])
    awayDefences.append(defence[away_idx[i]][i])

homeProbs = []
drawProbs = []
awayProbs = []
over2_5s = []
under2_5s = []

for i in range(len(data["HomeTeam"])):
    thisMatch = Match(homeAttacks[i], homeDefences[i], awayAttacks[i], awayDefences[i], homeAdvantage[i], rho[i], 8)
    outcomes = thisMatch.getOutcomeProbs()
    homeProbs.append(outcomes[0])
    drawProbs.append(outcomes[1])
    awayProbs.append(outcomes[2])
    scores = thisMatch.getScoreMatrix()
    over2_5 = 0
    under2_5 = 0
    for i in range(len(scores)):
        for j in range(len(scores[i])):
            if (i + j) > 2:
                over2_5 += scores[i][j]
            else:
                under2_5 += scores[i][j]

    over2_5s.append(over2_5)
    under2_5s.append(under2_5)

data["attackH"]  = homeAttacks
data["defenceH"] = homeDefences
data["attackA"]  = awayAttacks
data["defenceA"] = awayDefences
data["rho"] = rho
data["homeAdv"] = homeAdvantage
data["homeProb"] = homeProbs
data["drawProb"] = drawProbs
data["awayProb"] = awayProbs
data["FairHomeOdds"] = 1 / data["homeProb"]
data["FairDrawOdds"] = 1 / data["drawProb"]
data["FairAwayOdds"] = 1 / data["awayProb"]
data["Over2.5Prob"] = over2_5s
data["Under2.5Prob"] = under2_5s
data["FairOver2.5"] = 1 / data["Over2.5Prob"]
data["FairUnder2.5"] = 1 / data["Under2.5Prob"]

# %%
data.tail()
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 95  01/11/2025   Tottenham      Chelsea     0     1   A   3  15    1    9
# 96  01/11/2025   Liverpool  Aston Villa     2     0   H  16  10    4    3
# 97  02/11/2025    West Ham    Newcastle     3     1   H  15  12    9    4
# 98  02/11/2025    Man City  Bournemouth     3     1   H  15   8    8    5
# 99  03/11/2025  Sunderland      Everton     1     1   D  17   8    3    2
#
#     ...  homeProb  drawProb  awayProb  FairHomeOdds  FairDrawOdds  \
# 95  ...  0.407536  0.232125  0.360339      2.453769      4.308031
# 96  ...  0.638734  0.197506  0.163760      1.565597      5.063140
# 97  ...  0.356811  0.234933  0.408256      2.802602      4.256537
# 98  ...  0.816666  0.120382  0.062952      1.224491      8.306867
# 99  ...  0.551004  0.291733  0.157263      1.814869      3.427788
#
#     FairAwayOdds  Over2.5Prob  Under2.5Prob  FairOver2.5  FairUnder2.5
# 95      2.775165     0.624302      0.375698     1.601789      2.661713
# 96      6.106490     0.603967      0.396033     1.655721      2.525039
# 97      2.449444     0.609663      0.390337     1.640251      2.561886
# 98     15.885201     0.685857      0.314143     1.458029      3.183267
# 99      6.358792     0.279182      0.720818     3.581889      1.387313
#
# [5 rows x 37 columns]

# %%
bettingFrame = data.tail(n=2180)
bettingFrame["HomeWin"] = np.where(bettingFrame["FTR"] == "H", 1, 0)
bettingFrame["Draw"] = np.where(bettingFrame["FTR"] == "D", 1, 0)
bettingFrame["AwayWin"] = np.where(bettingFrame["FTR"] == "A", 1, 0)
bettingFrame["Over2.5"] = np.where(bettingFrame["FTHG"] + bettingFrame["FTAG"] > 2, 1, 0)
bettingFrame["Under2.5"] = np.where(bettingFrame["FTHG"] + bettingFrame["FTAG"] < 3, 1, 0)
bettingFrame.head()
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3475575809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["HomeWin"] = np.where(bettingFrame["FTR"] == "H", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3475575809.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Draw"] = np.where(bettingFrame["FTR"] == "D", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3475575809.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["AwayWin"] = np.where(bettingFrame["FTR"] == "A", 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3475575809.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Over2.5"] = np.where(bettingFrame["FTHG"] + bettingFrame["FTAG"] > 2, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3475575809.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Under2.5"] = np.where(bettingFrame["FTHG"] + bettingFrame["FTAG"] < 3, 1, 0)
#            Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  AST  \
# 200  01/01/2020      Burnley  Aston Villa     1     2   A  20  11    1    6
# 201  01/01/2020    Newcastle    Leicester     0     3   A   5  17    2   10
# 202  01/01/2020  Southampton    Tottenham     1     0   H  12  11    3    5
# 203  01/01/2020      Watford       Wolves     2     1   H   9  16    3    4
# 204  01/01/2020     Man City      Everton     2     1   H  16   7    7    2
#
#      ...  FairAwayOdds  Over2.5Prob  Under2.5Prob  FairOver2.5  FairUnder2.5  \
# 200  ...      3.016109     0.521849      0.478151     1.916263      2.091390
# 201  ...      1.502047     0.583848      0.416152     1.712773      2.402971
# 202  ...      1.809570     0.714920      0.285080     1.398758      3.507789
# 203  ...      1.934827     0.378885      0.621115     2.639320      1.610009
# 204  ...      9.557922     0.730703      0.269297     1.368545      3.713371
#
#      HomeWin  Draw  AwayWin  Over2.5  Under2.5
# 200        0     0        1        1         0
# 201        0     0        1        1         0
# 202        1     0        0        0         1
# 203        1     0        0        1         0
# 204        1     0        0        1         0
#
# [5 rows x 42 columns]

# %%
bettingFrame["ValueRatioHome"] = bettingFrame["MaxH"] * bettingFrame["homeProb"]
bettingFrame["ValueRatioDraw"] = bettingFrame["MaxD"] * bettingFrame["drawProb"]
bettingFrame["ValueRatioAway"] = bettingFrame["MaxA"] * bettingFrame["awayProb"]
bettingFrame["ValueOver2.5"] = bettingFrame["Max>2.5"] * bettingFrame["Over2.5Prob"]
bettingFrame["ValueUnder2.5"] = bettingFrame["Max<2.5"] * bettingFrame["Under2.5Prob"]
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/941000679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioHome"] = bettingFrame["MaxH"] * bettingFrame["homeProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/941000679.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioDraw"] = bettingFrame["MaxD"] * bettingFrame["drawProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/941000679.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueRatioAway"] = bettingFrame["MaxA"] * bettingFrame["awayProb"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/941000679.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueOver2.5"] = bettingFrame["Max>2.5"] * bettingFrame["Over2.5Prob"]
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/941000679.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ValueUnder2.5"] = bettingFrame["Max<2.5"] * bettingFrame["Under2.5Prob"]

# %%
bettingFrame["HomeBet"] = np.where(bettingFrame['ValueRatioHome'] > 1, 1, 0)
bettingFrame["AwayBet"] = np.where(bettingFrame['ValueRatioAway'] > 1, 1, 0)
bettingFrame["DrawBet"] = np.where(bettingFrame['ValueRatioDraw'] > 1, 1, 0)
bettingFrame["OverBet"] = np.where(bettingFrame["ValueOver2.5"] > 1, 1, 0)
bettingFrame["UnderBet"] = np.where(bettingFrame["ValueUnder2.5"] > 1, 1, 0)
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3255520189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["HomeBet"] = np.where(bettingFrame['ValueRatioHome'] > 1, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3255520189.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["AwayBet"] = np.where(bettingFrame['ValueRatioAway'] > 1, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3255520189.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["DrawBet"] = np.where(bettingFrame['ValueRatioDraw'] > 1, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3255520189.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["OverBet"] = np.where(bettingFrame["ValueOver2.5"] > 1, 1, 0)
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3255520189.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["UnderBet"] = np.where(bettingFrame["ValueUnder2.5"] > 1, 1, 0)

# %%
bettingFrame["Profit1X2"] = bettingFrame["HomeWin"] * bettingFrame["HomeBet"] * bettingFrame["MaxH"] + bettingFrame["AwayWin"] * bettingFrame["AwayBet"] * bettingFrame["MaxA"] - (bettingFrame["HomeBet"] + bettingFrame["AwayBet"])
bettingFrame["ProfitO/U"] = bettingFrame["Over2.5"] * bettingFrame["OverBet"] * bettingFrame["Max>2.5"] + bettingFrame["Under2.5"] * bettingFrame["UnderBet"] * bettingFrame["Max<2.5"] - (bettingFrame["OverBet"] + bettingFrame["UnderBet"])
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/4065714369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["Profit1X2"] = bettingFrame["HomeWin"] * bettingFrame["HomeBet"] * bettingFrame["MaxH"] + bettingFrame["AwayWin"] * bettingFrame["AwayBet"] * bettingFrame["MaxA"] - (bettingFrame["HomeBet"] + bettingFrame["AwayBet"])
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/4065714369.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bettingFrame["ProfitO/U"] = bettingFrame["Over2.5"] * bettingFrame["OverBet"] * bettingFrame["Max>2.5"] + bettingFrame["Under2.5"] * bettingFrame["UnderBet"] * bettingFrame["Max<2.5"] - (bettingFrame["OverBet"] + bettingFrame["UnderBet"])

# %%
fig, ax = plt.subplots()
ax.plot(bettingFrame["Date"], bettingFrame["ProfitO/U"].cumsum())

# %%
bettingFrame.OverBet.sum() + bettingFrame.UnderBet.sum()
# Out:
# 2078

# %%
bettingFrame["ProfitO/U"].sum()
# Out:
# -55.210000000000036

# %%
cleanProfits = [x for x in bettingFrame["ProfitO/U"] if x!=0]

# %%
np.mean(cleanProfits)
# Out:
# -0.026632899179932477

# %%
np.var(cleanProfits)
# Out:
# 1.136842304696708

# %%
import csv


with open("profitsBTTS.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(cleanProfits)

# %%
bettingFrame.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS',
#        'HST', 'AST', 'B365H', 'B365D', 'B365A', 'MaxH', 'MaxD', 'MaxA', 'AvgH',
#        'AvgD', 'AvgA', 'Max>2.5', 'Max<2.5', 'attackH', 'defenceH', 'attackA',
#        'defenceA', 'rho', 'homeAdv', 'homeProb', 'drawProb', 'awayProb',
#        'FairHomeOdds', 'FairDrawOdds', 'FairAwayOdds', 'Over2.5Prob',
#        'Under2.5Prob', 'FairOver2.5', 'FairUnder2.5', 'HomeWin', 'Draw',
#        'AwayWin', 'Over2.5', 'Under2.5', 'ValueRatioHome', 'ValueRatioDraw',
#        'ValueRatioAway', 'ValueOver2.5', 'ValueUnder2.5', 'HomeBet', 'AwayBet',
#        'DrawBet', 'OverBet', 'UnderBet', 'Profit1X2', 'ProfitO/U'],
#       dtype='object')

# %%
bettingFrame = bettingFrame[[
    "Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG",
    "FTR", "Max>2.5", "Max<2.5", "Over2.5Prob", "Under2.5Prob",
    "FairOver2.5", "FairUnder2.5", "Over2.5", "Under2.5",
    "ValueOver2.5", "ValueUnder2.5", "OverBet", "UnderBet", "ProfitO/U"
]]

# %%
bettingFrame.tail()
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  Max>2.5  Max<2.5  \
# 95  01/11/2025   Tottenham      Chelsea     0     1   A     1.75     2.12
# 96  01/11/2025   Liverpool  Aston Villa     2     0   H     1.56     2.50
# 97  02/11/2025    West Ham    Newcastle     3     1   H     1.80     2.17
# 98  02/11/2025    Man City  Bournemouth     3     1   H     1.55     2.55
# 99  03/11/2025  Sunderland      Everton     1     1   D     2.38     1.62
#
#     Over2.5Prob  Under2.5Prob  FairOver2.5  FairUnder2.5  Over2.5  Under2.5  \
# 95     0.624302      0.375698     1.601789      2.661713        0         1
# 96     0.603967      0.396033     1.655721      2.525039        0         1
# 97     0.609663      0.390337     1.640251      2.561886        1         0
# 98     0.685857      0.314143     1.458029      3.183267        1         0
# 99     0.279182      0.720818     3.581889      1.387313        0         1
#
#     ValueOver2.5  ValueUnder2.5  OverBet  UnderBet  ProfitO/U
# 95      1.092529       0.796480        1         0      -1.00
# 96      0.942188       0.990084        0         0       0.00
# 97      1.097393       0.847032        1         0       0.80
# 98      1.063079       0.801064        1         0       0.55
# 99      0.664454       1.167725        0         1       0.62

# %% [markdown]
# ### Beginning Of CHATGPT

# %%
df = bettingFrame.copy()

df = df[df["ProfitO/U"] != 0]

# %%
over_df = df[df["OverBet"] == 1].copy()

over_df["side"] = "Over"
over_df["model_prob"] = over_df["Over2.5Prob"]
over_df["market_odds"] = over_df["Max>2.5"]
over_df["value_ratio"] = over_df["ValueOver2.5"]

# %%
under_df = df[df["UnderBet"] == 1].copy()

under_df["side"] = "Under"
under_df["model_prob"] = under_df["Under2.5Prob"]
under_df["market_odds"] = under_df["Max<2.5"]
under_df["value_ratio"] = under_df["ValueUnder2.5"]

# %%
bets = pd.concat([over_df, under_df], ignore_index=True)

# %%
bets
# Out:
#             Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  Max>2.5  \
# 0     01/01/2020         Burnley  Aston Villa     1     2   A     1.93
# 1     01/01/2020       Newcastle    Leicester     0     3   A     2.01
# 2     01/01/2020     Southampton    Tottenham     1     0   H     1.70
# 3     01/01/2020        Man City      Everton     2     1   H     1.41
# 4     11/01/2020       Leicester  Southampton     1     2   A     1.69
# ...          ...             ...          ...   ...   ...  ..      ...
# 2073  25/10/2025       Brentford    Liverpool     3     2   H     1.58
# 2074  26/10/2025          Wolves      Burnley     2     3   A     2.30
# 2075  01/11/2025         Burnley      Arsenal     0     2   A     1.80
# 2076  01/11/2025  Crystal Palace    Brentford     2     0   H     1.80
# 2077  03/11/2025      Sunderland      Everton     1     1   D     2.38
#
#       Max<2.5  Over2.5Prob  Under2.5Prob  ...  Under2.5  ValueOver2.5  \
# 0        2.03     0.521849      0.478151  ...         0      1.007169
# 1        1.99     0.583848      0.416152  ...         0      1.173535
# 2        2.33     0.714920      0.285080  ...         1      1.215364
# 3        3.20     0.730703      0.269297  ...         0      1.030291
# 4        2.39     0.683140      0.316860  ...         0      1.154507
# ...       ...          ...           ...  ...       ...           ...
# 2073     2.50     0.594254      0.405746  ...         0      0.938921
# 2074     1.71     0.380705      0.619295  ...         0      0.875622
# 2075     2.14     0.488533      0.511467  ...         1      0.879359
# 2076     2.10     0.493534      0.506466  ...         1      0.888361
# 2077     1.62     0.279182      0.720818  ...         1      0.664454
#
#       ValueUnder2.5  OverBet  UnderBet  ProfitO/U   side  model_prob  \
# 0          0.970646        1         0       0.93   Over    0.521849
# 1          0.828142        1         0       1.01   Over    0.583848
# 2          0.664236        1         0      -1.00   Over    0.714920
# 3          0.861751        1         0       0.41   Over    0.730703
# 4          0.757295        1         0       0.69   Over    0.683140
# ...             ...      ...       ...        ...    ...         ...
# 2073       1.014365        0         1      -1.00  Under    0.405746
# 2074       1.058994        0         1      -1.00  Under    0.619295
# 2075       1.094540        0         1       1.14  Under    0.511467
# 2076       1.063579        0         1       1.10  Under    0.506466
# 2077       1.167725        0         1       0.62  Under    0.720818
#
#       market_odds value_ratio
# 0            1.93    1.007169
# 1            2.01    1.173535
# 2            1.70    1.215364
# 3            1.41    1.030291
# 4            1.69    1.154507
# ...           ...         ...
# 2073         2.50    1.014365
# 2074         1.71    1.058994
# 2075         2.14    1.094540
# 2076         2.10    1.063579
# 2077         1.62    1.167725
#
# [2078 rows x 23 columns]

# %%
BANKROLL = 1000

bets["log_return"] = np.log1p(bets["ProfitO/U"] / BANKROLL)

# %%
prob_bins = np.arange(0.25, 0.80, 0.05)

bets["prob_bucket"] = pd.cut(
    bets["model_prob"],
    bins=prob_bins
)

# %%
def kelly_stats(x):
    g_per_bet = x["log_return"].mean()
    log_sd = x["log_return"].std()

    cum_log = x["log_return"].cumsum()
    drawdown = cum_log - cum_log.cummax()

    return pd.Series({
        "n_bets": len(x),
        "g_per_bet": g_per_bet,
        "g_annual": g_per_bet * 365,
        "log_return_sd": log_sd,
        "max_drawdown": drawdown.min()
    })

# %%
prob_bucket_stats = (
    bets
    .groupby("prob_bucket")
    .apply(kelly_stats)
    .reset_index()
)
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3529162523.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("prob_bucket")
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3529162523.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(kelly_stats)

# %%
value_bins = [1.00, 1.02, 1.04, 1.06, 1.10, 1.14, 1.18, np.inf]

bets["value_bucket"] = pd.cut(
    bets["value_ratio"],
    bins=value_bins
)

value_bucket_stats = (
    bets
    .groupby("value_bucket")
    .apply(kelly_stats)
    .reset_index()
)
# Out:
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3698973985.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("value_bucket")
# /var/folders/c8/mqhljcz12rld881pkd18bzxc0000gn/T/ipykernel_65390/3698973985.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(kelly_stats)

# %%
value_bucket_stats
# Out:
#    value_bucket  n_bets  g_per_bet  g_annual  log_return_sd  max_drawdown
# 0   (1.0, 1.02]   184.0  -0.000046 -0.016636       0.000971     -0.015675
# 1  (1.02, 1.04]   181.0   0.000014  0.005017       0.001011     -0.018335
# 2  (1.04, 1.06]   203.0   0.000034  0.012376       0.001028     -0.014554
# 3   (1.06, 1.1]   342.0   0.000085  0.030979       0.001005     -0.011234
# 4   (1.1, 1.14]   271.0  -0.000131 -0.047666       0.001011     -0.049168
# 5  (1.14, 1.18]   228.0  -0.000055 -0.020004       0.001052     -0.019278
# 6   (1.18, inf]   669.0  -0.000056 -0.020517       0.001165     -0.060723

# %% [markdown]
# CONCLUSION: POTENTIAL VALUE IN [1.02,1.1] VALUE RANGE

# %%
filteredOver = bettingFrame.loc[
    (bettingFrame["ValueOver2.5"] > 1.02) &
    (bettingFrame["ValueOver2.5"] <= 1.10)
]
filteredUnder = bettingFrame.loc[
    (bettingFrame["ValueUnder2.5"] > 1.02) &
    (bettingFrame["ValueUnder2.5"] <= 1.10)
]

# %%
filteredOver
# Out:
#            Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  Max>2.5  Max<2.5  \
# 204  01/01/2020     Man City        Everton     2     1   H     1.41     3.20
# 215  11/01/2020       Wolves      Newcastle     1     1   D     2.10     1.87
# 216  11/01/2020    Tottenham      Liverpool     0     1   A     1.67     2.41
# 218  12/01/2020  Aston Villa       Man City     1     6   A     1.29     4.00
# 224  18/01/2020  Southampton         Wolves     2     3   A     2.10     1.86
# ..          ...          ...            ...   ...   ...  ..      ...      ...
# 87   26/10/2025  Bournemouth  Nott'm Forest     2     0   H     1.91     2.02
# 90   01/11/2025     Brighton          Leeds     3     0   H     1.85     2.05
# 95   01/11/2025    Tottenham        Chelsea     0     1   A     1.75     2.12
# 97   02/11/2025     West Ham      Newcastle     3     1   H     1.80     2.17
# 98   02/11/2025     Man City    Bournemouth     3     1   H     1.55     2.55
#
#      Over2.5Prob  Under2.5Prob  FairOver2.5  FairUnder2.5  Over2.5  Under2.5  \
# 204     0.730703      0.269297     1.368545      3.713371        1         0
# 215     0.498469      0.501531     2.006143      1.993895        0         1
# 216     0.641232      0.358768     1.559498      2.787316        0         1
# 218     0.805822      0.194178     1.240969      5.149916        1         0
# 224     0.518399      0.481601     1.929017      2.076407        1         0
# ..           ...           ...          ...           ...      ...       ...
# 87      0.543866      0.456134     1.838688      2.192338        0         1
# 90      0.587624      0.412376     1.701768      2.424973        1         0
# 95      0.624302      0.375698     1.601789      2.661713        0         1
# 97      0.609663      0.390337     1.640251      2.561886        1         0
# 98      0.685857      0.314143     1.458029      3.183267        1         0
#
#      ValueOver2.5  ValueUnder2.5  OverBet  UnderBet  ProfitO/U
# 204      1.030291       0.861751        1         0       0.41
# 215      1.046785       0.937863        1         0      -1.00
# 216      1.070857       0.864631        1         0      -1.00
# 218      1.039510       0.776712        1         0       0.29
# 224      1.088638       0.895778        1         0       1.10
# ..            ...            ...      ...       ...        ...
# 87       1.038784       0.921391        1         0      -1.00
# 90       1.087105       0.845370        1         0       0.85
# 95       1.092529       0.796480        1         0      -1.00
# 97       1.097393       0.847032        1         0       0.80
# 98       1.063079       0.801064        1         0       0.55
#
# [359 rows x 19 columns]

# %%
newBets = pd.concat([filteredOver, filteredUnder], ignore_index=True)

# %%
newBets
# Out:
#            Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  Max>2.5  \
# 0    01/01/2020        Man City         Everton     2     1   H     1.41
# 1    11/01/2020          Wolves       Newcastle     1     1   D     2.10
# 2    11/01/2020       Tottenham       Liverpool     0     1   A     1.67
# 3    12/01/2020     Aston Villa        Man City     1     6   A     1.29
# 4    18/01/2020     Southampton          Wolves     2     3   A     2.10
# ..          ...             ...             ...   ...   ...  ..      ...
# 721  05/10/2025     Aston Villa         Burnley     2     1   H     1.98
# 722  05/10/2025         Everton  Crystal Palace     2     1   H     2.33
# 723  26/10/2025          Wolves         Burnley     2     3   A     2.30
# 724  01/11/2025         Burnley         Arsenal     0     2   A     1.80
# 725  01/11/2025  Crystal Palace       Brentford     2     0   H     1.80
#
#      Max<2.5  Over2.5Prob  Under2.5Prob  FairOver2.5  FairUnder2.5  Over2.5  \
# 0       3.20     0.730703      0.269297     1.368545      3.713371        1
# 1       1.87     0.498469      0.501531     2.006143      1.993895        0
# 2       2.41     0.641232      0.358768     1.559498      2.787316        0
# 3       4.00     0.805822      0.194178     1.240969      5.149916        1
# 4       1.86     0.518399      0.481601     1.929017      2.076407        1
# ..       ...          ...           ...          ...           ...      ...
# 721     1.92     0.453697      0.546303     2.204114      1.830486        1
# 722     1.67     0.382147      0.617853     2.616796      1.618507        1
# 723     1.71     0.380705      0.619295     2.626704      1.614740        1
# 724     2.14     0.488533      0.511467     2.046945      1.955160        0
# 725     2.10     0.493534      0.506466     2.026203      1.974466        0
#
#      Under2.5  ValueOver2.5  ValueUnder2.5  OverBet  UnderBet  ProfitO/U
# 0           0      1.030291       0.861751        1         0       0.41
# 1           1      1.046785       0.937863        1         0      -1.00
# 2           1      1.070857       0.864631        1         0      -1.00
# 3           0      1.039510       0.776712        1         0       0.29
# 4           0      1.088638       0.895778        1         0       1.10
# ..        ...           ...            ...      ...       ...        ...
# 721         0      0.898320       1.048902        0         1      -1.00
# 722         0      0.890402       1.031815        0         1      -1.00
# 723         0      0.875622       1.058994        0         1      -1.00
# 724         1      0.879359       1.094540        0         1       1.14
# 725         1      0.888361       1.063579        0         1       1.10
#
# [726 rows x 19 columns]

# %%
cleanProfits = [x for x in newBets["ProfitO/U"] if x!=0]

# %%
np.mean(cleanProfits)
# Out:
# 0.053402203856749306

# %%
np.var(cleanProfits)
# Out:
# 1.0226637693615344

# %%
newBets = newBets.sort_values(by="Date")
fig, ax = plt.subplots()
ax.plot(newBets["Date"], newBets["ProfitO/U"].cumsum())
