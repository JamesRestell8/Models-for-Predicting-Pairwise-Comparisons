# %%
import sys
# !{sys.executable} -m pip install betfairlightweight
# Out:
# Collecting betfairlightweight
#   Using cached betfairlightweight-2.22.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: requests<2.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from betfairlightweight) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<2.33.0->betfairlightweight) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<2.33.0->betfairlightweight) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<2.33.0->betfairlightweight) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<2.33.0->betfairlightweight) (2025.1.31)
# Using cached betfairlightweight-2.22.1-py3-none-any.whl (69 kB)
# Installing collected packages: betfairlightweight
# Successfully installed betfairlightweight-2.22.1

# %%
import logging

import betfairlightweight

"""
Historic is the API endpoint that can be used to
download data betfair provide.

https://historicdata.betfair.com/#/apidocs
"""

# setup logging
logging.basicConfig(level=logging.INFO)  # change to DEBUG to see log all updates

# create trading instance
trading = betfairlightweight.APIClient("james.restell@icloud.com", "3g8C.Kd42KaF%cD", app_key="appKey")

# login
trading.login()

# get my data
my_data = trading.historic.get_my_data()
for i in my_data:
    print(i)

# get collection options (allows filtering)
collection_options = trading.historic.get_collection_options(
    "Horse Racing", "Basic Plan", 1, 3, 2017, 1, 3, 2017
)
print(collection_options)

# get advance basket data size
basket_size = trading.historic.get_data_size(
    "Horse Racing", "Basic Plan", 1, 3, 2017, 1, 3, 2017
)
print(basket_size)

# get file list
file_list = trading.historic.get_file_list(
    "Horse Racing",
    "Basic Plan",
    from_day=1,
    from_month=3,
    from_year=2017,
    to_day=31,
    to_month=3,
    to_year=2017,
    market_types_collection=["WIN", "PLACE"],
    countries_collection=["GB", "IE"],
    file_type_collection=["M"],
)
print(file_list)

# download the files
for file in file_list:
    print(file)
    download = trading.historic.download_file(file_path=file)
    print(download)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/betfairlightweight/baseclient.py:165, in BaseClient.cert(self)
#     164 try:
# --> 165     cert_path = os.listdir(self.certs)
#     166 except FileNotFoundError as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/certs'
#
# During handling of the above exception, another exception occurred:
#
# CertsError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/betfairlightweight/endpoints/login.py:48, in Login.request(self, method, params, session)
#      43 try:
#      44     response = session.post(
#      45         self.url,
#      46         data=self.data,
#      47         headers=self.client.login_headers,
# ---> 48         cert=self.client.cert,
#      49         timeout=(self.connect_timeout, self.read_timeout),
#      50     )
#      51 except requests.ConnectionError as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/betfairlightweight/baseclient.py:167, in BaseClient.cert(self)
#     166 except FileNotFoundError as e:
# --> 167     raise CertsError(str(e))
#     169 cert, key, pem = None, None, None
#
# CertsError: [Errno 2] No such file or directory: '/certs'
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[7], line 19
#      16 trading = betfairlightweight.APIClient("james.restell@icloud.com", "3g8C.Kd42KaF%cD", app_key="appKey")
#      18 # login
# ---> 19 trading.login()
#      21 # get my data
#      22 my_data = trading.historic.get_my_data()
#
# File /opt/anaconda3/lib/python3.12/site-packages/betfairlightweight/endpoints/login.py:30, in Login.__call__(self, session, lightweight)
#      19 def __call__(
#      20     self, session: requests.Session = None, lightweight: bool = None
#      21 ) -> Union[dict, LoginResource]:
#      22     """
#      23     Makes login request.
#      24
#    (...)
#      28     :rtype: LoginResource
#      29     """
# ---> 30     (response, response_json, elapsed_time) = self.request(
#      31         self.url, session=session
#      32     )
#      33     self.client.set_session_token(response_json.get("sessionToken"))
#      34     return self.process_response(
#      35         response_json, LoginResource, elapsed_time, lightweight
#      36     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/betfairlightweight/endpoints/login.py:54, in Login.request(self, method, params, session)
#      52     raise APIError(None, exception=e)
#      53 except Exception as e:
# ---> 54     raise APIError(None, exception=e)
#      55 elapsed_time = time.time() - time_sent
#      57 check_status_code(response)
#
# APIError: None
# Params: None
# Exception: [Errno 2] No such file or directory: '/certs'
