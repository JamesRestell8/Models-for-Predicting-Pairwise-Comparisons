# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import warnings
import os

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)
warnings.simplefilter("ignore", pd.errors.SettingWithCopyWarning)

# %%
folder = os.fsencode("data/horse")
dataframes = []
for file in sorted(os.listdir(folder)):
    filename = os.fsdecode(file)
    if filename.endswith(".csv"):
        df = pd.read_csv("data/horse/" + filename, low_memory=False)
        dataframes.append(df)

data = pd.concat(dataframes, axis=0)

# %%
data = data[[
    "rid", "decimalPrice", "isFav", "runners", "margin", "res_win", "res_place"
]]
data.dropna()
data.describe()
# Out:
#                  rid   decimalPrice          isFav        runners  \
# count  343044.000000  343044.000000  343044.000000  343044.000000
# mean   117370.319312       0.120658       0.108231      11.281847
# std     45049.775581       0.118108       0.310672       3.926604
# min         2.000000       0.000999       0.000000       2.000000
# 25%     99059.000000       0.038462       0.000000       8.000000
# 50%    129331.000000       0.083333       0.000000      11.000000
# 75%    151313.000000       0.166667       0.000000      14.000000
# max    172749.000000       0.961538       1.000000      40.000000
#
#               margin        res_win      res_place
# count  343044.000000  343044.000000  343044.000000
# mean        1.210366       0.101337       0.277116
# std         0.080763       0.301775       0.447575
# min         1.003417       0.000000       0.000000
# 25%         1.163878       0.000000       0.000000
# 50%         1.199133       0.000000       0.000000
# 75%         1.236824       0.000000       1.000000
# max         2.595183       1.000000       1.000000

# %%
len(pd.unique(data["rid"]))
# Out:
# 34712
